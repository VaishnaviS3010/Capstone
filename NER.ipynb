# %% [markdown]
# **<center><font size = "5">Create custom NER model<center>**
# ***

# %%
# !pip install spacy

# %%
# !python3 -m spacy download en_core_web_lg

# %%
from __future__ import unicode_literals, print_function

import pandas as pd
import os, time

from pathlib import Path
from tqdm import tqdm 
from spacy.training import Example
from spacy import displacy
import spacy
import base64

# %% [markdown]
# ### NER pipeline

# %%
nlpSpacy = spacy.load("en_core_web_lg")
 
print(nlpSpacy.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('known_exploited_vulnerabilities.csv')


# Create a random sample of 300 rows
sample_df = df.sample(n=300, random_state=1)

# Display the sample
print(sample_df)
# Out:
#                  cveID vendorProject
# 919      CVE-2023-2136        Google  \
# 298     CVE-2021-35394       Realtek
# 926      CVE-2014-0196         Linux
# 323   CVE-2017-1000486      Primetek
# 239     CVE-2019-16256   SIMalliance
# ...                ...           ...
# 322      CVE-2015-7450           IBM
# 311     CVE-2021-22017        VMware
# 831      CVE-2022-3236        Sophos
# 1004    CVE-2023-41993         Apple
# 1125    CVE-2022-24816         OSGeo
#
#                                                 product
# 919                                       Chromium Skia  \
# 298               Jungle Software Development Kit (SDK)
# 926                                              Kernel
# 323                              Primefaces Application
# 239                                     Toolbox Browser
# ...                                                 ...
# 322   WebSphere Application Server and Server Hyperv...
# 311                                      vCenter Server
# 831                                            Firewall
# 1004                                  Multiple Products
# 1125                                            JAI-EXT
#
#                                       vulnerabilityName   dateAdded
# 919   Google Chrome Skia Integer Overflow Vulnerability  2023-04-21  \
# 298   Realtek Jungle SDK Remote Code Execution Vulne...  2021-12-10
# 926           Linux Kernel Race Condition Vulnerability  2023-05-12
# 323   Primetek Primefaces Remote Code Execution Vuln...  2022-01-10
# 239   SIMalliance Toolbox Browser Command Injection ...  2021-11-03
# ...                                                 ...         ...
# 322   IBM WebSphere Application Server and Server Hy...  2022-01-10
# 311       VMware vCenter Server Improper Access Control  2022-01-10
# 831        Sophos Firewall Code Injection Vulnerability  2022-09-23
# 1004  Apple Multiple Products WebKit Code Execution ...  2023-09-25
# 1125  OSGeo GeoServer JAI-EXT Code Injection Vulnera...  2024-06-26
#
#                                        shortDescription
# 919   Google Chromium Skia contains an integer overf...  \
# 298   RealTek Jungle SDK contains multiple memory co...
# 926   Linux Kernel contains a race condition vulnera...
# 323   Primetek Primefaces is vulnerable to a weak en...
# 239   SIMalliance Toolbox Browser contains an comman...
# ...                                                 ...
# 322   Serialized-object interfaces in certain IBM an...
# 311   Rhttproxy as used in vCenter Server contains a...
# 831   A code injection vulnerability in the User Por...
# 1004  Apple iOS, iPadOS, macOS, and Safari WebKit co...
# 1125  OSGeo GeoServer JAI-EXT contains a code inject...
#
#                                          requiredAction     dueDate
# 919              Apply updates per vendor instructions.  2023-05-12  \
# 298              Apply updates per vendor instructions.  2021-12-24
# 926   The impacted product is end-of-life and should...  2023-06-02
# 323              Apply updates per vendor instructions.  2022-07-10
# 239              Apply updates per vendor instructions.  2022-05-03
# ...                                                 ...         ...
# 322              Apply updates per vendor instructions.  2022-07-10
# 311              Apply updates per vendor instructions.  2022-01-24
# 831              Apply updates per vendor instructions.  2022-10-14
# 1004  Apply mitigations per vendor instructions or d...  2023-10-16
# 1125  Apply mitigations per vendor instructions or d...  2024-07-17
#
#      knownRansomwareCampaignUse
# 919                     Unknown  \
# 298                     Unknown
# 926                     Unknown
# 323                     Unknown
# 239                     Unknown
# ...                         ...
# 322                     Unknown
# 311                     Unknown
# 831                     Unknown
# 1004                    Unknown
# 1125                    Unknown
#
#                                                   notes             cwes
# 919   https://chromereleases.googleblog.com/2023/04/...          CWE-190
# 298     https://nvd.nist.gov/vuln/detail/CVE-2021-35394  CWE-78, CWE-138
# 926   https://lkml.iu.edu/hypermail/linux/kernel/160...          CWE-362
# 323   https://nvd.nist.gov/vuln/detail/CVE-2017-1000486          CWE-326
# 239     https://nvd.nist.gov/vuln/detail/CVE-2019-16256              NaN
# ...                                                 ...              ...
# 322      https://nvd.nist.gov/vuln/detail/CVE-2015-7450           CWE-94
# 311     https://nvd.nist.gov/vuln/detail/CVE-2021-22017           CWE-23
# 831   https://www.sophos.com/en-us/security-advisori...           CWE-94
# 1004  https://support.apple.com/en-us/HT213926, http...          CWE-754
# 1125  This vulnerability affects a common open-sourc...           CWE-94
#
# [300 rows x 11 columns]

# %%
df.head()
# Out:
#             cveID vendorProject             product
# 0  CVE-2021-27104     Accellion                 FTA  \
# 1  CVE-2021-27102     Accellion                 FTA
# 2  CVE-2021-27101     Accellion                 FTA
# 3  CVE-2021-27103     Accellion                 FTA
# 4  CVE-2021-21017         Adobe  Acrobat and Reader
#
#                                    vulnerabilityName   dateAdded
# 0   Accellion FTA OS Command Injection Vulnerability  2021-11-03  \
# 1   Accellion FTA OS Command Injection Vulnerability  2021-11-03
# 2          Accellion FTA SQL Injection Vulnerability  2021-11-03
# 3  Accellion FTA Server-Side Request Forgery (SSR...  2021-11-03
# 4  Adobe Acrobat and Reader Heap-based Buffer Ove...  2021-11-03
#
#                                     shortDescription
# 0  Accellion FTA contains an OS command injection...  \
# 1  Accellion FTA contains an OS command injection...
# 2  Accellion FTA contains a SQL injection vulnera...
# 3  Accellion FTA contains a server-side request f...
# 4  Acrobat Acrobat and Reader contain a heap-base...
#
#                            requiredAction     dueDate
# 0  Apply updates per vendor instructions.  2021-11-17  \
# 1  Apply updates per vendor instructions.  2021-11-17
# 2  Apply updates per vendor instructions.  2021-11-17
# 3  Apply updates per vendor instructions.  2021-11-17
# 4  Apply updates per vendor instructions.  2021-11-17
#
#   knownRansomwareCampaignUse                                            notes
# 0                      Known  https://nvd.nist.gov/vuln/detail/CVE-2021-27104  \
# 1                      Known  https://nvd.nist.gov/vuln/detail/CVE-2021-27102
# 2                      Known  https://nvd.nist.gov/vuln/detail/CVE-2021-27101
# 3                      Known  https://nvd.nist.gov/vuln/detail/CVE-2021-27103
# 4                    Unknown  https://nvd.nist.gov/vuln/detail/CVE-2021-21017
#
#               cwes
# 0   CWE-20, CWE-78
# 1   CWE-20, CWE-78
# 2  CWE-89, CWE-138
# 3          CWE-918
# 4          CWE-122

# %%
text1 = sample_df["vulnerabilityName"]
text1.head()
# Out:
# 919    Google Chrome Skia Integer Overflow Vulnerability
# 298    Realtek Jungle SDK Remote Code Execution Vulne...
# 926            Linux Kernel Race Condition Vulnerability
# 323    Primetek Primefaces Remote Code Execution Vuln...
# 239    SIMalliance Toolbox Browser Command Injection ...
# Name: vulnerabilityName, dtype: object

# %%
text2 = sample_df["shortDescription"]
text2.head()
# Out:
# 919    Google Chromium Skia contains an integer overf...
# 298    RealTek Jungle SDK contains multiple memory co...
# 926    Linux Kernel contains a race condition vulnera...
# 323    Primetek Primefaces is vulnerable to a weak en...
# 239    SIMalliance Toolbox Browser contains an comman...
# Name: shortDescription, dtype: object

# %%
# Save text1 to a file
with open('text1.txt', 'w') as file1:
    file1.write('\n'.join(text1))

# Save text2 to a file
with open('text2.txt', 'w') as file2:
    file2.write('\n'.join(text2))

# %%
file = open('text2.txt')
text = file.read()
file.close()
doc = nlpSpacy(text)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Chromium Skia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contains an integer overflow vulnerability that allows a remote attacker, who has compromised the renderer process, to potentially perform a sandbox escape via a crafted HTML page. This vulnerability affects
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Chrome
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and ChromeOS, Android, Flutter, and possibly other products.<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RealTek Jungle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  SDK contains multiple memory corruption vulnerabilities which can allow an attacker to perform remote code execution.<br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux Kernel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  contains a race condition vulnerability within the n_tty_write function that allows local users to cause a denial-of-service (DoS) or gain privileges via read and write operations with long strings.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Primetek Primefaces
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is vulnerable to a weak encryption flaw resulting in remote code execution<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SIMalliance Toolbox Browser
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  contains an command injection vulnerability that could allow remote attackers to retrieve location and IMEI information or execute a range of other attacks by modifying the attack message.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Windows Adobe Font Manager Library
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contains an unspecified vulnerability when handling specially crafted multi-master fonts (
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adobe Type
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  PostScript format) that allows for remote code execution for all systems except
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Windows 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . For systems running
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Windows 10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , an attacker who successfully exploited the vulnerability could execute code in an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AppContainer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  sandbox context with limited privileges and capabilities.<br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Chrome WebAudio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  contains a use-after-free vulnerability that allows a remote attacker to potentially exploit heap corruption via a crafted HTML page.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Internet Explorer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contains a use-after-free vulnerability that allows a remote attacker to execute arbitrary code via a crafted web site that triggers access to an object that (1) was not properly allocated or (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) is deleted, as demonstrated by a CDwnBindInfo object.<br>Use-after-free vulnerability in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft Internet Explorer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  allows remote attackers to execute remote code via a crafted web site that triggers access to a deleted object.<br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apache CouchDB
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  contains an insecure default initialization of resource vulnerability which can allow an attacker to escalate to administrative privileges.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple iOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , iPadOS, macOS, tvOS, and watchOS contain a time-of-check/time-of-use (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TOCTOU
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ) memory corrupti

# %%
for entity in doc.ents:
  print(f"Name of the entity {entity.text} type is {entity.label_}")
# Out:
# Name of the entity Google Chromium Skia type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity RealTek Jungle type is PERSON
# Name of the entity Linux Kernel type is PRODUCT
# Name of the entity Primetek Primefaces type is ORG
# Name of the entity SIMalliance Toolbox Browser type is PERSON
# Name of the entity Microsoft Windows Adobe Font Manager Library type is ORG
# Name of the entity Adobe Type type is PRODUCT
# Name of the entity 1 type is CARDINAL
# Name of the entity Windows 10 type is PRODUCT
# Name of the entity Windows 10 type is PRODUCT
# Name of the entity AppContainer type is ORG
# Name of the entity Google Chrome WebAudio type is PRODUCT
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity 2 type is CARDINAL
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity Apache CouchDB type is PRODUCT
# Name of the entity Apple iOS type is ORG
# Name of the entity TOCTOU type is ORG
# Name of the entity Pointer Authentication type is FAC
# Name of the entity Adobe Flash Player type is PRODUCT
# Name of the entity SAP NetWeaver type is PRODUCT
# Name of the entity Microsoft Exchange Server type is ORG
# Name of the entity CVE-2022-41082 type is ORG
# Name of the entity Microsoft Windows Power type is ORG
# Name of the entity Microsoft Defender SmartScreen type is ORG
# Name of the entity Mark type is PERSON
# Name of the entity MikroTik type is ORG
# Name of the entity NetBIOS type is PERSON
# Name of the entity Ivanti Endpoint Manager Cloud Service Appliance type is ORG
# Name of the entity Dahua IP type is FAC
# Name of the entity NetKeyboard type is ORG
# Name of the entity downloadServerip type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Win32k type is ORG
# Name of the entity Zyxel P660HN type is ORG
# Name of the entity the Remote System Log type is ORG
# Name of the entity SSLVPN SMA100 type is PERSON
# Name of the entity NETGEAR type is ORG
# Name of the entity Oracle type is ORG
# Name of the entity Java type is GPE
# Name of the entity Citrix type is PRODUCT
# Name of the entity Adobe Acrobat type is PERSON
# Name of the entity Adobe Flash Player type is PRODUCT
# Name of the entity Microsoft Exchange Server type is ORG
# Name of the entity ProxyLogon type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity macOS WebKit type is PRODUCT
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity Microsoft Windows Cryptographic Next Generation type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity McAfee Total Protection type is ORG
# Name of the entity MTP type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Win32k type is ORG
# Name of the entity Win32k EoP. type is PRODUCT
# Name of the entity Progress MOVEit Transfer type is ORG
# Name of the entity MOVEit Transfer's type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity the DirectX Graphics Kernel type is LAW
# Name of the entity Photo Station type is FAC
# Name of the entity Spring type is DATE
# Name of the entity VMware Tanzu type is ORG
# Name of the entity VeloCloud type is PERSON
# Name of the entity Atlassian type is NORP
# Name of the entity Atlassian Confluence Data Center type is ORG
# Name of the entity JBoss Seam 2 type is ORG
# Name of the entity JBoss Enterprise Application Platform 4.3.0 type is ORG
# Name of the entity Red Hat Linux type is ORG
# Name of the entity Microsoft Windows Scripting Engine type is ORG
# Name of the entity 4.3 type is CARDINAL
# Name of the entity CVE type is ORG
# Name of the entity Adobe Acrobat type is PERSON
# Name of the entity Windows type is PRODUCT
# Name of the entity TrueType type is PRODUCT
# Name of the entity NETGEAR type is ORG
# Name of the entity DGN2200 type is NORP
# Name of the entity Arm Mali GPU Kernel Driver type is ORG
# Name of the entity Realtek AP-Router SDK type is ORG
# Name of the entity Google Chromium V8 Engine type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity the Windows Adobe Type Manager Library type is PRODUCT
# Name of the entity OpenType type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Cisco ASA type is ORG
# Name of the entity Microsoft Windows Internet Shortcut type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity NAS File Station type is FAC
# Name of the entity Red Hat JBoss Enterprise Application Platform type is ORG
# Name of the entity Zyxel type is ORG
# Name of the entity URI type is ORG
# Name of the entity Microsoft Windows SmartScreen type is ORG
# Name of the entity SmartScreen type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Safari type is PERSON
# Name of the entity Web Content type is PRODUCT
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity Adobe Acrobat type is PERSON
# Name of the entity Google Chromium Blink type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity Adobe Reader type is ORG
# Name of the entity Acrobat type is PRODUCT
# Name of the entity Elasticsearch type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Red Hat type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Exim type is ORG
# Name of the entity Samsung type is ORG
# Name of the entity Exynos type is ORG
# Name of the entity Aurora type is PRODUCT
# Name of the entity acdb type is PRODUCT
# Name of the entity third type is ORDINAL
# Name of the entity Qualcomm type is ORG
# Name of the entity Android type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Microsoft Open Management Infrastructure type is ORG
# Name of the entity Azure VM Management Extensions type is ORG
# Name of the entity 443 type is CARDINAL
# Name of the entity Adobe Reader type is ORG
# Name of the entity Action View type is EVENT
# Name of the entity Microsoft Windows CSRSS type is ORG
# Name of the entity CVE-2012-1823 type is CARDINAL
# Name of the entity Microsoft Windows Runtime type is ORG
# Name of the entity Microsoft Win32k type is ORG
# Name of the entity Microsoft Windows Error Reporting Service type is ORG
# Name of the entity Netwrix Auditor User Activity Video Recording type is PERSON
# Name of the entity AUTHORITY\SYSTEM type is ORG
# Name of the entity 9004/TCP type is PRODUCT
# Name of the entity Adobe ColdFusion type is PRODUCT
# Name of the entity NAS File Station type is FAC
# Name of the entity LG N1A1 NAS 3718.510 type is ORG
# Name of the entity JavaScript type is PRODUCT
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Arm Mali Graphics Processing Unit type is ORG
# Name of the entity Juniper Junos type is ORG
# Name of the entity EX Series type is PRODUCT
# Name of the entity Mozilla Firefox type is ORG
# Name of the entity WebGPU IPC Framework type is ORG
# Name of the entity NetWeaver Application Server Java Platforms type is ORG
# Name of the entity two type is CARDINAL
# Name of the entity futex type is ORG
# Name of the entity Remote Code Execution type is PRODUCT
# Name of the entity Google Chrome type is ORG
# Name of the entity FreeType type is ORG
# Name of the entity Load_SBit_Png type is ORG
# Name of the entity CVE-2020 type is CARDINAL
# Name of the entity Windows type is PRODUCT
# Name of the entity CVE-2020 type is CARDINAL
# Name of the entity Android type is ORG
# Name of the entity Google Chromium V8 Engine type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity the Java Runtime Environment type is ORG
# Name of the entity JRE type is WORK_OF_ART
# Name of the entity Oracle type is ORG
# Name of the entity Java type is GPE
# Name of the entity Microsoft type is ORG
# Name of the entity Windows Mark type is PRODUCT
# Name of the entity MOTW type is ORG
# Name of the entity Microsoft Office type is ORG
# Name of the entity Microsoft Exchange Server Validation Key type is ORG
# Name of the entity Ivanti Pulse Connect Secure Collaboration Suite type is ORG
# Name of the entity Dahua IP type is FAC
# Name of the entity Microsoft Office type is ORG
# Name of the entity Google Chromium V8 Engine type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity H/W type is PRODUCT
# Name of the entity DDNS type is ORG
# Name of the entity ncc2 binary file type is ORG
# Name of the entity Mozilla Firefox type is ORG
# Name of the entity Firefox ESR type is ORG
# Name of the entity Thunderbird type is PRODUCT
# Name of the entity SVG Animation type is ORG
# Name of the entity Firefox type is ORG
# Name of the entity Tor type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Zoho ManageEngine PAM360 type is ORG
# Name of the entity Access Manager Plus type is PRODUCT
# Name of the entity Unraid type is ORG
# Name of the entity CVE type is ORG
# Name of the entity CVE-2020-5847 type is CARDINAL
# Name of the entity Microsoft type is ORG
# Name of the entity Windows MSHTML Platform type is PRODUCT
# Name of the entity Oracle WebLogic Server type is ORG
# Name of the entity Apache Commons type is ORG
# Name of the entity Microsoft Windows Scripting Engine type is ORG
# Name of the entity Pulse Connect Secure type is ORG
# Name of the entity Microsoft Office type is ORG
# Name of the entity Excel type is PRODUCT
# Name of the entity OGNL type is ORG
# Name of the entity Apache Struts type is PRODUCT
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity Android Framework type is PRODUCT
# Name of the entity Google Pixel type is ORG
# Name of the entity Zimbra Collaboration Suite type is FAC
# Name of the entity ZCS type is ORG
# Name of the entity Microsoft Windows Common Log File System type is ORG
# Name of the entity CLFS type is ORG
# Name of the entity Liferay Portal type is ORG
# Name of the entity Microsoft Office Excel type is ORG
# Name of the entity FEATHEADER type is ORG
# Name of the entity JavaScript type is PRODUCT
# Name of the entity The Simple Network Management Protocol (SNMP type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity XE type is PRODUCT
# Name of the entity Microsoft Word type is ORG
# Name of the entity RTF type is ORG
# Name of the entity Progress Telerik type is PRODUCT
# Name of the entity Google Chromium V8 Engine type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity Adobe Reader type is ORG
# Name of the entity Acrobat type is PRODUCT
# Name of the entity Microsoft Windows Win32k type is ORG
# Name of the entity Microsoft Windows Installer type is ORG
# Name of the entity Fortinet FortiOS type is ORG
# Name of the entity FortiProxy type is ORG
# Name of the entity Atlassian Confluence Data Center type is ORG
# Name of the entity Confluence type is PRODUCT
# Name of the entity Confluence type is PRODUCT
# Name of the entity GIGABYTE App Center type is FAC
# Name of the entity AORUS Graphics Engine type is ORG
# Name of the entity OC GURU II type is PRODUCT
# Name of the entity Citrix Content Collaboration type is PRODUCT
# Name of the entity ShareFile type is ORG
# Name of the entity F5 BIG-IP type is ORG
# Name of the entity the Cisco Cluster Management Protocol type is ORG
# Name of the entity CMP type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity Cisco IOS XE Software type is ORG
# Name of the entity Active Directory Certificate Services type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Safari type is PERSON
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity Tenda AC1900 Router AC15 type is ORG
# Name of the entity Microsoft Word type is ORG
# Name of the entity Microsoft Works Suites type is ORG
# Name of the entity Microsoft Windows Print Spooler type is ORG
# Name of the entity Discovery and Configuration Protocol type is PRODUCT
# Name of the entity PN-DCP type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity Microsoft Windows Common Log File System type is ORG
# Name of the entity CLFS type is ORG
# Name of the entity IBM Data Risk type is ORG
# Name of the entity Microsoft Office Publisher type is ORG
# Name of the entity Microsoft Exchange Server type is ORG
# Name of the entity ProxyLogon type is ORG
# Name of the entity Adobe Flash Player type is ORG
# Name of the entity SWF type is ORG
# Name of the entity Trend Micro type is ORG
# Name of the entity OfficeScan type is NORP
# Name of the entity OfficeScan type is NORP
# Name of the entity Adobe Flash Player type is ORG
# Name of the entity The Veeam Distribution Service type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Mozilla Firefox type is ORG
# Name of the entity Thunderbird type is PRODUCT
# Name of the entity nsDocShell type is ORG
# Name of the entity NAS File Station type is FAC
# Name of the entity Core type is PRODUCT
# Name of the entity Google Chromium WebP type is PRODUCT
# Name of the entity the WebP Codec type is PRODUCT
# Name of the entity Grandstream UCM6200 type is FAC
# Name of the entity Cisco IOS XR Distance Vector Multicast Routing Protocol type is ORG
# Name of the entity IGMP type is ORG
# Name of the entity IGMP type is ORG
# Name of the entity Rejetto HTTP File Server type is LAW
# Name of the entity Adobe Flash Player type is PRODUCT
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity OLE type is ORG
# Name of the entity F5 BIG-IP Configuration type is ORG
# Name of the entity CVE-2023-46748 type is ORG
# Name of the entity Veritas Backup Exec type is ORG
# Name of the entity DSL-2750B type is PRODUCT
# Name of the entity search_params type is GPE
# Name of the entity Cloud Foundation Server type is ORG
# Name of the entity Trend Micro Apex One type is ORG
# Name of the entity OfficeScan type is NORP
# Name of the entity Worry-Free Business Security type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Windows type is PRODUCT
# Name of the entity Cisco IP Phones type is ORG
# Name of the entity Multiple D-Link type is ORG
# Name of the entity Palo Alto Networks type is ORG
# Name of the entity the Windows AppX Deployment Server type is ORG
# Name of the entity Google Chromium Portals type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Palo Alto Networks type is ORG
# Name of the entity PAN-OS GlobalProtect type is ORG
# Name of the entity Docker Desktop Community Edition type is FAC
# Name of the entity Mozilla Firefox type is ORG
# Name of the entity XSLT type is FAC
# Name of the entity NETGEAR type is ORG
# Name of the entity Microsoft Windows User Profile Service type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Safari type is PERSON
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity SonicWall Email Security type is ORG
# Name of the entity SonicWall Email Security type is ORG
# Name of the entity CVE-2021-20022 type is DATE
# Name of the entity CVE-2021-20023 type is CARDINAL
# Name of the entity RARLAB type is ORG
# Name of the entity UnRAR type is PRODUCT
# Name of the entity Linux type is PRODUCT
# Name of the entity UNIX type is ORG
# Name of the entity SysAid Server type is ORG
# Name of the entity Arm Mali GPU Kernel Driver type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity macOS WebKit type is PRODUCT
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity ForgeRock Access Management type is ORG
# Name of the entity one type is CARDINAL
# Name of the entity three type is CARDINAL
# Name of the entity Masthead type is ORG
# Name of the entity Microsoft Exchange Server type is ORG
# Name of the entity DotNetNuke type is ORG
# Name of the entity DNN type is PERSON
# Name of the entity Apple iOS type is ORG
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity Mozilla Firefox type is ORG
# Name of the entity Thunderbird type is PRODUCT
# Name of the entity IonMonkey type is ORG
# Name of the entity Remote Code Execution type is LAW
# Name of the entity PAN-OS type is ORG
# Name of the entity GlobalProtect Portal or GlobalProtect Gateway Interface type is ORG
# Name of the entity OleAut32.dll type is ORG
# Name of the entity OLE type is ORG
# Name of the entity Microsoft type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity D-Link DIR-820L type is ORG
# Name of the entity Microsoft Win32k type is ORG
# Name of the entity Windows AppXSVC type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Apache Kylin type is PERSON
# Name of the entity Microsoft Windows SmartScreen type is ORG
# Name of the entity SmartScreen type is ORG
# Name of the entity Dasan GPON Routers type is PERSON
# Name of the entity Samsung type is ORG
# Name of the entity CVE-2021-25369 type is CARDINAL
# Name of the entity CVE-2021-25370 type is QUANTITY
# Name of the entity Zyxel ATP type is ORG
# Name of the entity USG FLEX type is ORG
# Name of the entity ZyWALL/USG type is PRODUCT
# Name of the entity Mozilla Firefox type is ORG
# Name of the entity Thunderbird type is PRODUCT
# Name of the entity JavaScript type is PRODUCT
# Name of the entity Array.pop type is ORG
# Name of the entity Multiple NETGEAR type is ORG
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity Adobe Flash Player type is PRODUCT
# Name of the entity the Common Industrial Protocol type is LAW
# Name of the entity Cisco IOS type is ORG
# Name of the entity 64 type is CARDINAL
# Name of the entity sw_perf_event_destroy type is PERSON
# Name of the entity Explotation type is PRODUCT
# Name of the entity FXC type is ORG
# Name of the entity Word type is PRODUCT
# Name of the entity Ruckus Wireless Access Point ( type is PRODUCT
# Name of the entity AP type is ORG
# Name of the entity AP type is ORG
# Name of the entity RCE type is ORG
# Name of the entity Ruckus ZoneDirector type is PRODUCT
# Name of the entity SmartZone type is ORG
# Name of the entity Solo APs. type is PERSON
# Name of the entity Adobe Reader type is ORG
# Name of the entity Adobe type is ORG
# Name of the entity Java type is GPE
# Name of the entity Cisco Secure Access Control System type is ORG
# Name of the entity Google Chromium V8 Engine type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity Atlassian type is NORP
# Name of the entity Fortinet type is ORG
# Name of the entity FilePath type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity Remote Shell type is ORG
# Name of the entity Secure Shell type is ORG
# Name of the entity Cisco type is ORG
# Name of the entity Ivanti Endpoint Manager Mobile type is ORG
# Name of the entity EPMM type is ORG
# Name of the entity MobileIron Core type is ORG
# Name of the entity Microsoft Enhanced Cryptographic Provider type is ORG
# Name of the entity Arm Bifrost type is LOC
# Name of the entity Valhall type is FAC
# Name of the entity Red Hat JBoss RichFaces Framework type is ORG
# Name of the entity UserResource type is ORG
# Name of the entity Java type is GPE
# Name of the entity org.ajax4jsf.resource type is PERSON
# Name of the entity UserResource$UriData type is ORG
# Name of the entity Adobe Flash Player type is PRODUCT
# Name of the entity Android Kernel type is PRODUCT
# Name of the entity the Linux Kernel type is ORG
# Name of the entity CVE-2020-0041 type is CARDINAL
# Name of the entity Jenkins type is PERSON
# Name of the entity Apple iOS type is ORG
# Name of the entity ChakraCore type is PERSON
# Name of the entity Microsoft Windows Event Tracing type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity IOS XE Software type is ORG
# Name of the entity IPVPN type is ORG
# Name of the entity Windows AppX Deployment Service type is ORG
# Name of the entity AppXSVC type is ORG
# Name of the entity Citrix NetScaler SD-WAN Enterprise type is PRODUCT
# Name of the entity Citrix CloudBridge type is PRODUCT
# Name of the entity XenMobile type is ORG
# Name of the entity Microsoft Win32k type is ORG
# Name of the entity Microsoft Windows Print Spooler type is ORG
# Name of the entity Fortinet type is ORG
# Name of the entity Google Chromium Blink type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity WordPress Snap Creek Duplicator type is ORG
# Name of the entity Wordpress type is PRODUCT
# Name of the entity Duplicator and Dulplicator Pro type is WORK_OF_ART
# Name of the entity the DirectX Graphics Kernel type is LAW
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity Microsoft PowerPoint type is ORG
# Name of the entity Microsoft Windows User Profile Service type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Delta Electronics type is ORG
# Name of the entity DOPSoft 2 type is PRODUCT
# Name of the entity ExceptionDelegator type is NORP
# Name of the entity Apache Struts 2 type is PRODUCT
# Name of the entity 2.2.3.1 type is CARDINAL
# Name of the entity Microsoft Windows Local Security Authority type is ORG
# Name of the entity LSA type is ORG
# Name of the entity NTLM type is ORG
# Name of the entity Sun xVM VirtualBox type is ORG
# Name of the entity RARLAB WinRAR type is ORG
# Name of the entity Microsoft Windows Adobe Font Manager Library type is ORG
# Name of the entity Adobe Type type is PRODUCT
# Name of the entity 1 type is CARDINAL
# Name of the entity Windows 10 type is PRODUCT
# Name of the entity Windows 10 type is PRODUCT
# Name of the entity AppContainer type is ORG
# Name of the entity NAS type is ORG
# Name of the entity Photo Station type is FAC
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity Multiple Qualcomm type is ORG
# Name of the entity VMware Cloud Foundation type is ORG
# Name of the entity Microsoft Internet Explorer type is ORG
# Name of the entity Microsoft Windows CryptoAPI type is ORG
# Name of the entity Crypt32.dll type is PERSON
# Name of the entity Elliptic Curve Cryptography type is ORG
# Name of the entity CurveBall type is ORG
# Name of the entity Zoho ManageEngine ADSelfService type is ORG
# Name of the entity WebRTC type is ORG
# Name of the entity WebRTC type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Network Address Translation type is WORK_OF_ART
# Name of the entity NAT type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity Apple iOS type is ORG
# Name of the entity Safari type is PERSON
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity Cisco AnyConnect Secure Mobility Client type is ORG
# Name of the entity IPC type is ORG
# Name of the entity Windows type is PRODUCT
# Name of the entity Arcserve UDP type is ORG
# Name of the entity SolarWinds type is ORG
# Name of the entity Apache Shiro type is PRODUCT
# Name of the entity Google Chromium type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity Fortinet type is ORG
# Name of the entity Microsoft Windows Error Reporting Service type is ORG
# Name of the entity Cisco NX-OS type is ORG
# Name of the entity Netis WF2419 type is PRODUCT
# Name of the entity Microsoft Windows AppX Installer type is ORG
# Name of the entity Google Chromium PopupBlocker type is ORG
# Name of the entity Chromium type is ORG
# Name of the entity Google Chrome type is ORG
# Name of the entity Microsoft Edge type is ORG
# Name of the entity Opera type is ORG
# Name of the entity The Simple Network Management Protocol (SNMP type is ORG
# Name of the entity Cisco IOS type is ORG
# Name of the entity XE type is PRODUCT
# Name of the entity sapi/cgi/cgi_main.c type is ORG
# Name of the entity graphapi type is ORG
# Name of the entity phpinfo type is GPE
# Name of the entity 4.3 type is CARDINAL
# Name of the entity Oracle Fusion Middleware Access type is ORG
# Name of the entity Access type is ORG
# Name of the entity Microsoft Office type is ORG
# Name of the entity Oracle WebLogic Server type is ORG
# Name of the entity IIOP type is ORG
# Name of the entity Oracle type is ORG
# Name of the entity Cisco Small Business RV160 type is ORG
# Name of the entity RV260, RV340 type is ORG
# Name of the entity RV345 Series Routers type is FAC
# Name of the entity Cisco IOS XE Web UI type is ORG
# Name of the entity 15 type is CARDINAL
# Name of the entity Treck type is PERSON
# Name of the entity IBM type is ORG
# Name of the entity URI type is ORG
# Name of the entity the User Portal type is LOC
# Name of the entity Webadmin type is PERSON
# Name of the entity Sophos Firewall type is PRODUCT
# Name of the entity Apple iOS type is ORG
# Name of the entity Safari type is PERSON
# Name of the entity Apple Safari type is ORG
# Name of the entity non-Apple type is ORG
# Name of the entity Jiffle type is PRODUCT

# %% [markdown]
# ## Annotate the text for NER
#
# Navigate to
#
# https://tecoholic.github.io/ner-annotator/
#
# and make all the custom NER and annotate the entities on the text one by one

# %% [markdown]
# ## Make a Spacy custom NER MODEL

# %%
import json
 
with open('annotations 1.json', 'r') as f:
    data = json.load(f)
    
print(data['annotations'][0])
# Out:
# ['Google Chrome Skia Integer Overflow Vulnerability', {'entities': [[0, 6, 'ORG'], [7, 13, 'PRODUCT'], [14, 18, 'LIBRARY'], [19, 35, 'FIELD']]}]

# %%
data['classes']
# Out:
# ['PRODUCT', 'FIELD', 'LIBRARY', 'ORG', 'FUNCTION']

# %% [markdown]
# ## Create empty model

# %%
training_data = data.copy()
training_data['classes'] = data['classes']
training_data['annotations'] = []
for text, annotation in data['annotations']:
    try:
        if text!="" and len(annotation['entities']) > 0:
            temp_dict = {}
            temp_dict['text'] = text
            temp_dict['entities'] = []
            for ent in annotation['entities']:
                start = ent[0]
                end = ent[1]
                label = ent[2].upper()
                temp_dict['entities'].append((start, end, label))
        training_data['annotations'].append(temp_dict)
    except:
        pass
print(training_data)
# Out:
# {'classes': ['PRODUCT', 'FIELD', 'LIBRARY', 'ORG', 'FUNCTION'], 'annotations': [{'text': 'Google Chrome Skia Integer Overflow Vulnerability', 'entities': [(0, 6, 'ORG'), (7, 13, 'PRODUCT'), (14, 18, 'LIBRARY'), (19, 35, 'FIELD')]}, {'text': 'Realtek Jungle SDK Remote Code Execution Vulnerability', 'entities': [(0, 7, 'ORG'), (8, 18, 'PRODUCT'), (19, 40, 'FIELD')]}, {'text': 'Linux Kernel Race Condition Vulnerability', 'entities': [(0, 5, 'ORG'), (6, 27, 'FIELD')]}, {'text': 'Primetek Primefaces Remote Code Execution Vulnerability', 'entities': [(0, 8, 'ORG'), (9, 19, 'PRODUCT'), (20, 41, 'FIELD')]}, {'text': 'SIMalliance Toolbox Browser Command Injection Vulnerability', 'entities': [(0, 11, 'ORG'), (12, 27, 'PRODUCT'), (28, 45, 'FIELD')]}, {'text': 'Microsoft Windows Adobe Font Manager Library Remote Code Execution Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 17, 'PRODUCT'), (18, 36, 'FUNCTION'), (45, 66, 'FIELD')]}, {'text': 'Google Chrome WebAudio Use-After-Free Vulnerability', 'entities': [(0, 6, 'ORG'), (7, 13, 'PRODUCT'), (14, 22, 'LIBRARY'), (23, 37, 'FIELD')]}, {'text': 'Microsoft Internet Explorer Use-After-Free Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 27, 'PRODUCT'), (28, 42, 'FIELD')]}, {'text': 'Microsoft Internet Explorer Use-After-Free Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 27, 'PRODUCT'), (28, 42, 'FIELD')]}, {'text': 'Apache CouchDB Insecure Default Initialization of Resource Vulnerability', 'entities': [(0, 6, 'ORG'), (7, 14, 'PRODUCT'), (32, 58, 'FIELD')]}, {'text': 'Apple Multiple Products Memory Corruption Vulnerability', 'entities': [(0, 5, 'ORG'), (6, 23, 'PRODUCT'), (24, 41, 'FIELD')]}, {'text': 'Adobe Flash Player Heap-Based Buffer Overflow Vulnerability', 'entities': [(0, 5, 'ORG'), (6, 18, 'PRODUCT'), (30, 45, 'FIELD')]}, {'text': 'SAP NetWeaver Unrestricted File Upload Vulnerability', 'entities': [(0, 3, 'ORG'), (4, 13, 'PRODUCT'), (14, 38, 'FIELD')]}, {'text': 'Microsoft Exchange Server Server-Side Request Forgery Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 25, 'PRODUCT'), (38, 53, 'FIELD')]}, {'text': 'Microsoft Windows Power Dependency Coordinator Privilege Escalation Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 17, 'PRODUCT'), (18, 46, 'FUNCTION'), (47, 67, 'FIELD')]}, {'text': 'Microsoft Windows Win32k Privilege Escalation Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 17, 'PRODUCT'), (18, 24, 'LIBRARY'), (25, 45, 'FIELD')]}, {'text': 'Microsoft Defender SmartScreen Security Feature Bypass Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 18, 'PRODUCT'), (19, 30, 'FUNCTION'), (31, 54, 'FIELD')]}, {'text': 'MikroTik RouterOS Stack-Based Buffer Overflow Vulnerability', 'entities': [(0, 8, 'ORG'), (9, 17, 'PRODUCT'), (30, 45, 'FIELD')]}, {'text': 'Ivanti Endpoint Manager Cloud Service Appliance (EPM CSA) Code Injection Vulnerability ', 'entities': [(0, 6, 'ORG'), (7, 23, 'PRODUCT'), (24, 47, 'FUNCTION'), (58, 72, 'FIELD')]}, {'text': 'Dahua IP Camera Authentication Bypass Vulnerability', 'entities': [(0, 5, 'ORG'), (6, 15, 'PRODUCT'), (16, 37, 'FIELD')]}, {'text': 'ThinkPHP Remote Code Execution Vulnerability', 'entities': [(0, 8, 'ORG'), (9, 30, 'FIELD')]}, {'text': 'D-Link DWL-2600AP Access Point Command Injection Vulnerability', 'entities': [(0, 6, 'ORG'), (7, 30, 'PRODUCT'), (31, 48, 'FIELD')]}, {'text': 'Microsoft Win32k Privilege Escalation Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 16, 'LIBRARY'), (17, 37, 'FIELD')]}, {'text': 'Zyxel P660HN-T1A Routers Command Injection Vulnerability', 'entities': [(0, 5, 'ORG'), (6, 24, 'PRODUCT'), (25, 42, 'FIELD')]}, {'text': 'SonicWall SSLVPN SMA100 SQL Injection Vulnerability', 'entities': [(0, 9, 'ORG'), (10, 23, 'PRODUCT'), (24, 37, 'FIELD')]}, {'text': 'NETGEAR WNR2000v5 Router Buffer Overflow Vulnerability', 'entities': [(0, 7, 'ORG'), (8, 24, 'PRODUCT'), (25, 40, 'FIELD')]}, {'text': 'Oracle Java SE Integrity Check Vulnerability', 'entities': [(0, 6, 'ORG'), (7, 14, 'PRODUCT'), (15, 30, 'FIELD')]}, {'text': 'Cit ...

# %% [markdown]
# ### Configuration variables

# %%
modelSpacy = None
n_iter=100

# %% [markdown]
# ### Load the model

# %%
if modelSpacy is not None:
    nlp = spacy.load(modelSpacy)  
    print("Loaded model '%s'" % modelSpacy)
else:
    nlp = spacy.blank('en')  
    print("Created blank 'en' model")
# Out:
# Created blank 'en' model

# %% [markdown]
# ### Set up pipeline

# %%
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ### Train the NER model

# %%
#getting all the entities
for annotations in training_data["annotations"]:
    for ent in annotations['entities']:
        ner.add_label(ent[2])
        
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        losses = {}
        for text, annotations in tqdm(data["annotations"]):
            try:
                if text!="":
                    example = Example.from_dict(nlp.make_doc(text), annotations)
                    #Update the model
                    nlp.update(
                        [example],  
                        drop=0.5,  
                        sgd=optimizer,
                        losses=losses)
            except:
                pass
        print(losses)
# Out:
# 100%|██████████| 300/300 [00:02<00:00, 129.48it/s]
# {'ner': 1281.9669577487327}
# 100%|██████████| 300/300 [00:01<00:00, 150.50it/s]
# {'ner': 840.0535356115821}
# 100%|██████████| 300/300 [00:02<00:00, 144.71it/s]
# {'ner': 766.8872955690897}
# 100%|██████████| 300/300 [00:01<00:00, 151.61it/s]
# {'ner': 621.9582066397048}
# 100%|██████████| 300/300 [00:02<00:00, 147.53it/s]
# {'ner': 579.9971837363139}
# 100%|██████████| 300/300 [00:01<00:00, 150.47it/s]
# {'ner': 522.984526827317}
# 100%|██████████| 300/300 [00:01<00:00, 150.89it/s]
# {'ner': 489.3154441261283}
# 100%|██████████| 300/300 [00:01<00:00, 150.77it/s]
# {'ner': 408.7254339386059}
# 100%|██████████| 300/300 [00:01<00:00, 150.95it/s]
# {'ner': 382.1992948738301}
# 100%|██████████| 300/300 [00:02<00:00, 148.82it/s]
# {'ner': 370.49139371129695}
# 100%|██████████| 300/300 [00:01<00:00, 151.16it/s]
# {'ner': 356.29948546571694}
# 100%|██████████| 300/300 [00:01<00:00, 150.84it/s]
# {'ner': 329.30499883781556}
# 100%|██████████| 300/300 [00:01<00:00, 151.11it/s]
# {'ner': 330.8009111004652}
# 100%|██████████| 300/300 [00:02<00:00, 147.61it/s]
# {'ner': 317.90230533663527}
# 100%|██████████| 300/300 [00:02<00:00, 142.30it/s]
# {'ner': 315.89062723259366}
# 100%|██████████| 300/300 [00:02<00:00, 146.58it/s]
# {'ner': 248.43661278295198}
# 100%|██████████| 300/300 [00:02<00:00, 144.16it/s]
# {'ner': 281.3452590747915}
# 100%|██████████| 300/300 [00:02<00:00, 147.47it/s]
# {'ner': 247.0803682023971}
# 100%|██████████| 300/300 [00:02<00:00, 148.80it/s]
# {'ner': 201.76588304577834}
# 100%|██████████| 300/300 [00:01<00:00, 151.32it/s]
# {'ner': 228.53862924777167}
# 100%|██████████| 300/300 [00:01<00:00, 151.67it/s]
# {'ner': 154.91019140699026}
# 100%|██████████| 300/300 [00:01<00:00, 151.95it/s]
# {'ner': 188.83103589074562}
# 100%|██████████| 300/300 [00:02<00:00, 147.44it/s]
# {'ner': 222.3397565547952}
# 100%|██████████| 300/300 [00:02<00:00, 146.69it/s]
# {'ner': 187.77009310556218}
# 100%|██████████| 300/300 [00:01<00:00, 151.52it/s]
# {'ner': 168.47857202230705}
# 100%|██████████| 300/300 [00:02<00:00, 147.88it/s]
# {'ner': 168.17331818481333}
# 100%|██████████| 300/300 [00:01<00:00, 151.59it/s]
# {'ner': 163.0097961921721}
# 100%|██████████| 300/300 [00:01<00:00, 151.99it/s]
# {'ner': 172.55120058600164}
# 100%|██████████| 300/300 [00:01<00:00, 152.38it/s]
# {'ner': 154.3882574220234}
# 100%|██████████| 300/300 [00:01<00:00, 150.78it/s]
# {'ner': 160.34974528754518}
# 100%|██████████| 300/300 [00:02<00:00, 144.08it/s]
# {'ner': 154.11349355710573}
# 100%|██████████| 300/300 [00:01<00:00, 152.19it/s]
# {'ner': 173.05557579307848}
# 100%|██████████| 300/300 [00:02<00:00, 147.66it/s]
# {'ner': 182.07398041901888}
# 100%|██████████| 300/300 [00:02<00:00, 148.99it/s]
# {'ner': 143.96682784036523}
# 100%|██████████| 300/300 [00:02<00:00, 147.65it/s]
# {'ner': 140.3697529599119}
# 100%|██████████| 300/300 [00:02<00:00, 147.07it/s]
# {'ner': 135.2666948198769}
# 100%|██████████| 300/300 [00:01<00:00, 151.59it/s]
# {'ner': 154.88981302857542}
# 100%|██████████| 300/300 [00:01<00:00, 151.80it/s]
# {'ner': 139.52329179664832}
# 100%|██████████| 300/300 [00:01<00:00, 152.90it/s]
# {'ner': 110.35705882160639}
# 100%|██████████| 300/300 [00:02<00:00, 144.72it/s]
# {'ner': 136.60331439014095}
# 100%|██████████| 300/300 [00:02<00:00, 143.98it/s]
# {'ner': 97.42932154182118}
# 100%|██████████| 300/300 [00:01<00:00, 150.71it/s]
# {'ner': 106.80441110350164}
# 100%|██████████| 300/300 [00:02<00:00, 147.06it/s]
# {'ner': 103.07596747027989}
# 100%|██████████| 300/300 [00:02<00:00, 135.36it/s]
# {'ner': 116.82368093521004}
# 100%|██████████| 300/300 [00:02<00:00, 146.30it/s]
# {'ner': 83.85791959313549}
# 100%|██████████| 300/300 [00:02<00:00, 139.29it/s]
# {'ner': 129.29232206087488}
# 100%|██████████| 300/300 [00:02<00:00, 144.33it/s]
# {'ner': 94.26230627899699}
# 100%|██████████| 300/300 [00:02<00:00, 141.22it/s]
# {'ner': 119.53293453730436}
# 100%|██████████| 300/300 [00:02<00:00, 146.79it/s]
# {'ner': 135.30904889523342}
# 100%|██████████| 300/300 [00:01<00:00, 152.23it/s]
# {'ner': 99.05282406612254}
# 100%|██████████| 300/300 [00:01<00:00, 152.99it/s]
# {'ner': 104.03353796514313}
# 100%|██████████| 300/300 [00:01<00:00, 150.71it/s]
# {'ner': 102.3485964308939}
# 100%|██████████| 300/300 [00:01<00:00, 152.96it/s]
# {'ner': 93.07427838620458}
# 100%|██████████| 300/300 [00:01<00:00, 152.97it/s]
# {'ner': 107.37481146386799}
# 100%|██████████| 300/300 [00:01<00:00, 151.47it/s]
# {'ner': 103.04913830032989}
# 100%|██████████| 300/300 [00:02<00:00, 146.60it/s]
# {'ner': 104.32575380293689}
# 100%|██████████| 300/300 [00:02<00:00, 144.45it/s]
# {'ner': 101.0787321629625}
# 100%|██████████| 300/300 [00:02<00:00, 144.52it/s]
# {'ner': 117.87798588377488}
# 100%|██████████| 300/300 [00:01<00:00, 150.35it/s]
# {'ner': 93.17317045790986}
# 100%|██████████| 300/300 [00:02<00:00, 143.90it/s]
# {'ner': 64.82527822835137}
# 100%|██████████| 300/300 [00:02<00:00, 145.84it/s]
# {'ner': 96.67483149959716}
# 100%|██████████| 300/300 [00:01<00:00, 155.38it/s]
# {'ner': 108.8433394990334}
# 100%|██████████| 300/300 [00:01<00:00, 155.36it/s]
# {'ner': 85.56142929553701}
# 100%|██████████| 300/300 [00:01<00:00, 155.01it/s]
# {'ner': 92.84505525870621}
# 100%|██████████| 300/300 [00:01<00:00, 155.42it/s]
# {'ner': 78.9593197678924}
# 100%|██████████| 300/300 [00:02<00:00, 145.31it/s]
# {'ner': 87.23420945885502}
# 100%|██████████| 300/300 [00:02<00:00, 148.08it/s]
# {'ner': 84.99744159560021}
# 100%|██████████| 300/300 [00:02<00:00, 139.13it/s]
# {'ner': 94.70047409114488}
# 100%|██████████| 300/300 [00:01<00:00, 150.00it/s]
# {'ner': 112.141392301845}
# 100%|██████████| 300/300 [00:01<00:00, 152.57it/s]
# {'ner': 84.49978640322291}
# 100%|██████████| 300/300 [00:01<00:00, 150.74it/s]
# {'ner': 89.25598050707883}
# 100%|██████████| 300/300 [00:01<00:00, 151.54it/s]
# {'ner': 94.38121175283409}
# 100%|██████████| 300/300 [00:01<00:00, 152.32it/s]
# {'ner': 87.1340484571713}
# 100%|██████████| 300/300 [00:02<00:00, 145.96it/s]
# {'ner': 79.42422373441713}
# 100%|██████████| 300/300 [00:01<00:00, 152.46it/s]
# {'ner': 83.78087170918491}
# 100%|██████████| 300/300 [00:01<00:00, 150.73it/s]
# {'ner': 75.36906342589768}
# 100%|██████████| 300/300 [00:01<00:00, 152.79it/s]
# {'ner': 105.47241901896996}
# 100%|██████████| 300/300 [00:01<00:00, 152.55it/s]
# {'ner': 58.23608758745549}
# 100%|██████████| 300/300 [00:01<00:00, 152.49it/s]
# {'ner': 69.91618530163997}
# 100%|██████████| 300/300 [00:01<00:00, 152.69it/s]
# {'ner': 79.10005010381546}
# 100%|██████████| 300/300 [00:01<00:00, 150.31it/s]
# {'ner': 73.92910966754287}
# 100%|██████████| 300/300 [00:01<00:00, 152.78it/s]
# {'ner': 83.7119213343703}
# 100%|██████████| 300/300 [00:01<00:00, 151.76it/s]
# {'ner': 74.03410367556239}
# 100%|██████████| 300/300 [00:01<00:00, 152.78it/s]
# {'ner': 74.87024671173259}
# 100%|██████████| 300/300 [00:02<00:00, 145.79it/s]
# {'ner': 64.82319179774322}
# 100%|██████████| 300/300 [00:02<00:00, 149.33it/s]
# {'ner': 68.39488677394267}
# 100%|██████████| 300/300 [00:02<00:00, 145.33it/s]
# {'ner': 72.07917041642511}
# 100%|██████████| 300/300 [00:01<00:00, 151.00it/s]
# {'ner': 61.427306504864106}
# 100%|██████████| 300/300 [00:01<00:00, 150.11it/s]
# {'ner': 103.35852474489408}
# 100%|██████████| 300/300 [00:01<00:00, 151.40it/s]
# {'ner': 69.8113688070033}
# 100%|██████████| 300/300 [00:02<00:00, 146.86it/s]
# {'ner': 53.66956653237426}
# 100%|██████████| 300/300 [00:01<00:00, 152.00it/s]
# {'ner': 72.62520633347525}
# 100%|██████████| 300/300 [00:02<00:00, 148.80it/s]
# {'ner': 72.89700632710158}
# 100%|██████████| 300/300 [00:02<00:00, 143.44it/s]
# {'ner': 77.8504591670615}
# 100%|██████████| 300/300 [00:01<00:00, 150.90it/s]
# {'ner': 74.84911607340268}
# 100%|██████████| 300/300 [00:01<00:00, 152.27it/s]
# {'ner': 65.63667760831115}
# 100%|██████████| 300/300 [00:01<00:00, 152.49it/s]
# {'ner': 72.43354419085117}
# 100%|██████████| 300/300 [00:01<00:00, 150.82it/s]
# {'ner': 71.09343940391909}
# 100%|██████████| 300/300 [00:01<00:00, 152.87it/s]
# {'ner': 77.6210527065922}
# 100%|██████████| 300/300 [00:01<00:00, 152.72it/s]
# {'ner': 75.89528029367014}

# %% [markdown]
# ### Test the trained model

# %%
for annotations in training_data["annotations"]:
    doc = nlp(annotations['text'])
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('Google', 'ORG'), ('Chrome', 'PRODUCT'), ('Skia', 'LIBRARY'), ('Integer Overflow', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chrome', 'PRODUCT', 3), ('Skia', 'LIBRARY', 3), ('Integer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Realtek', 'ORG'), ('Jungle SDK', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Realtek', 'ORG', 3), ('Jungle', 'PRODUCT', 3), ('SDK', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Linux Kernel Race', 'PRODUCT')]
# Tokens [('Linux', 'PRODUCT', 3), ('Kernel', 'PRODUCT', 1), ('Race', 'PRODUCT', 1), ('Condition', '', 2), ('Vulnerability', '', 2)]
# Entities [('Primetek', 'ORG'), ('Primefaces', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Primetek', 'ORG', 3), ('Primefaces', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('SIMalliance', 'ORG'), ('Toolbox Browser', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('SIMalliance', 'ORG', 3), ('Toolbox', 'PRODUCT', 3), ('Browser', 'PRODUCT', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Adobe Font Manager Library', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Adobe', 'FUNCTION', 3), ('Font', 'FUNCTION', 1), ('Manager', 'FUNCTION', 1), ('Library', 'FUNCTION', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chrome', 'PRODUCT'), ('WebAudio', 'LIBRARY'), ('Use-After-Free', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chrome', 'PRODUCT', 3), ('WebAudio', 'LIBRARY', 3), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apache', 'ORG'), ('CouchDB', 'PRODUCT'), ('Initialization of Resource', 'FIELD')]
# Tokens [('Apache', 'ORG', 3), ('CouchDB', 'PRODUCT', 3), ('Insecure', '', 2), ('Default', '', 2), ('Initialization', 'FIELD', 3), ('of', 'FIELD', 1), ('Resource', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Flash Player', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('Heap', '', 2), ('-', '', 2), ('Based', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('SAP', 'ORG'), ('NetWeaver', 'PRODUCT'), ('Unrestricted File Upload', 'FIELD')]
# Tokens [('SAP', 'ORG', 3), ('NetWeaver', 'PRODUCT', 3), ('Unrestricted', 'FIELD', 3), ('File', 'FIELD', 1), ('Upload', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Exchange Server', 'PRODUCT'), ('Request Forgery', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Exchange', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Server', '', 2), ('-', '', 2), ('Side', '', 2), ('Request', 'FIELD', 3), ('Forgery', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Power Dependency Coordinator', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Power', 'FUNCTION', 3), ('Dependency', 'FUNCTION', 1), ('Coordinator', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Win32k', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Win32k', 'LIBRARY', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Defender', 'PRODUCT'), ('SmartScreen', 'FUNCTION'), ('Security Feature Bypass', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Defender', 'PRODUCT', 3), ('SmartScreen', 'FUNCTION', 3), ('Security', 'FIELD', 3), ('Feature', 'FIELD', 1), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('MikroTik', 'ORG'), ('RouterOS', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('MikroTik', 'ORG', 3), ('RouterOS', 'PRODUCT', 3), ('Stack', '', 2), ('-', '', 2), ('Based', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Ivanti', 'ORG'), ('Endpoint Manager', 'PRODUCT'), ('Cloud Service Appliance', 'FUNCTION'), ('Code Injection', 'FIELD')]
# Tokens [('Ivanti', 'ORG', 3), ('Endpoint', 'PRODUCT', 3), ('Manager', 'PRODUCT', 1), ('Cloud', 'FUNCTION', 3), ('Service', 'FUNCTION', 1), ('Appliance', 'FUNCTION', 1), ('(', '', 2), ('EPM', '', 2), ('CSA', '', 2), (')', '', 2), ('Code', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Dahua', 'ORG'), ('IP Camera', 'PRODUCT'), ('Authentication Bypass', 'FIELD')]
# Tokens [('Dahua', 'ORG', 3), ('IP', 'PRODUCT', 3), ('Camera', 'PRODUCT', 1), ('Authentication', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('ThinkPHP', 'ORG'), ('Remote Code Execution', 'FIELD')]
# Tokens [('ThinkPHP', 'ORG', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('D-Link', 'ORG'), ('DWL-2600AP Access Point', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('D', 'ORG', 3), ('-', 'ORG', 1), ('Link', 'ORG', 1), ('DWL-2600AP', 'PRODUCT', 3), ('Access', 'PRODUCT', 1), ('Point', 'PRODUCT', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Win32k', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Win32k', 'LIBRARY', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Zyxel', 'ORG'), ('P660HN-T1A Routers', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('Zyxel', 'ORG', 3), ('P660HN', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('T1A', 'PRODUCT', 1), ('Routers', 'PRODUCT', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('SonicWall', 'ORG'), ('SSLVPN SMA100', 'PRODUCT'), ('SQL Injection', 'FIELD')]
# Tokens [('SonicWall', 'ORG', 3), ('SSLVPN', 'PRODUCT', 3), ('SMA100', 'PRODUCT', 1), ('SQL', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('NETGEAR', 'ORG'), ('WNR2000v5 Router', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('NETGEAR', 'ORG', 3), ('WNR2000v5', 'PRODUCT', 3), ('Router', 'PRODUCT', 1), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Oracle', 'ORG'), ('Java SE', 'PRODUCT'), ('Integrity Check', 'FIELD')]
# Tokens [('Oracle', 'ORG', 3), ('Java', 'PRODUCT', 3), ('SE', 'PRODUCT', 1), ('Integrity', 'FIELD', 3), ('Check', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Citrix', 'ORG'), ('StoreFront Server', 'PRODUCT'), ('XML External Entity (XXE) Processing', 'FIELD')]
# Tokens [('Citrix', 'ORG', 3), ('StoreFront', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('XML', 'FIELD', 3), ('External', 'FIELD', 1), ('Entity', 'FIELD', 1), ('(', 'FIELD', 1), ('XXE', 'FIELD', 1), (')', 'FIELD', 1), ('Processing', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Acrobat and Reader', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Acrobat', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Reader', 'PRODUCT', 1), ('Stack', '', 2), ('-', '', 2), ('Based', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Flash Player', 'PRODUCT'), ('Cross-Site Scripting', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('Cross', 'FIELD', 3), ('-', 'FIELD', 1), ('Site', 'FIELD', 1), ('Scripting', 'FIELD', 1), ('(', '', 2), ('XSS', '', 2), (')', '', 2), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Exchange Server', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Exchange', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('iOS, iPadOS, and macOS', 'PRODUCT'), ('Webkit', 'LIBRARY'), ('Use-After-Free', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('iOS', 'PRODUCT', 3), (',', 'PRODUCT', 1), ('iPadOS', 'PRODUCT', 1), (',', 'PRODUCT', 1), ('and', 'PRODUCT', 1), ('macOS', 'PRODUCT', 1), ('Webkit', 'LIBRARY', 3), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Android Kernel', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Android', 'PRODUCT', 3), ('Kernel', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('CNG Key Isolation Service', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('CNG', 'FUNCTION', 3), ('Key', 'FUNCTION', 1), ('Isolation', 'FUNCTION', 1), ('Service', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Authenticode Signature Verification', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Authenticode', 'FUNCTION', 3), ('Signature', 'FUNCTION', 1), ('Verification', 'FUNCTION', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('McAfee', 'ORG'), ('Total Protection', 'PRODUCT'), ('Improper Privilege Management', 'FIELD')]
# Tokens [('McAfee', 'ORG', 3), ('Total', 'PRODUCT', 3), ('Protection', 'PRODUCT', 1), ('(', '', 2), ('MTP', '', 2), (')', '', 2), ('Improper', 'FIELD', 3), ('Privilege', 'FIELD', 1), ('Management', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Win32k', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Win32k', 'LIBRARY', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Progress', 'ORG'), ('MOVEit Transfer', 'PRODUCT'), ('SQL Injection', 'FIELD')]
# Tokens [('Progress', 'ORG', 3), ('MOVEit', 'PRODUCT', 3), ('Transfer', 'PRODUCT', 1), ('SQL', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('DirectX Graphics Kernel', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('DirectX', 'LIBRARY', 3), ('Graphics', 'LIBRARY', 1), ('Kernel', 'LIBRARY', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('QNAP', 'ORG'), ('Photo Station', 'FUNCTION'), ('Externally Controlled Reference', 'FIELD')]
# Tokens [('QNAP', 'ORG', 3), ('Photo', 'FUNCTION', 3), ('Station', 'FUNCTION', 1), ('Externally', 'FIELD', 3), ('Controlled', 'FIELD', 1), ('Reference', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('VMware', 'ORG'), ('Tanzu', 'PRODUCT'), ('Spring', 'FUNCTION'), ('Directory Traversal', 'FIELD')]
# Tokens [('VMware', 'ORG', 3), ('Tanzu', 'PRODUCT', 3), ('Spring', 'FUNCTION', 3), ('Cloud', '', 2), ('Config', '', 2), ('Directory', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('VMware', 'ORG'), ('SD-WAN Edge', 'FUNCTION'), ('VeloCloud', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('VMware', 'ORG', 3), ('SD', 'FUNCTION', 3), ('-', 'FUNCTION', 1), ('WAN', 'FUNCTION', 1), ('Edge', 'FUNCTION', 1), ('by', '', 2), ('VeloCloud', 'PRODUCT', 3), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Atlassian', 'ORG'), ('Confluence Server and Data Center', 'PRODUCT'), ('Path Traversal', 'FIELD')]
# Tokens [('Atlassian', 'ORG', 3), ('Confluence', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('and', 'PRODUCT', 1), ('Data', 'PRODUCT', 1), ('Center', 'PRODUCT', 1), ('Path', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Atlassian', 'ORG'), ('Confluence Data Center and Server', 'PRODUCT'), ('Improper Authorization', 'FIELD')]
# Tokens [('Atlassian', 'ORG', 3), ('Confluence', 'PRODUCT', 3), ('Data', 'PRODUCT', 1), ('Center', 'PRODUCT', 1), ('and', 'PRODUCT', 1), ('Server', 'PRODUCT', 1), ('Improper', 'FIELD', 3), ('Authorization', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Red Hat', 'ORG'), ('Linux', 'PRODUCT'), ('JBoss Seam', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Red', 'ORG', 3), ('Hat', 'ORG', 1), ('Linux', 'PRODUCT', 3), ('JBoss', 'FUNCTION', 3), ('Seam', 'FUNCTION', 1), ('2', '', 2), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Scripting Engine', 'FUNCTION'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Scripting', 'FUNCTION', 3), ('Engine', 'FUNCTION', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('GNU', 'ORG'), ('Bourne-Again Shell', 'PRODUCT'), ('Arbitrary Code Execution', 'FIELD')]
# Tokens [('GNU', 'ORG', 3), ('Bourne', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('Again', 'PRODUCT', 1), ('Shell', 'PRODUCT', 1), ('(', '', 2), ('Bash', '', 2), (')', '', 2), ('Arbitrary', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Acrobat and Reader', 'PRODUCT'), ('Out-of-Bounds Write', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Acrobat', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Reader', 'PRODUCT', 1), ('Out', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Bounds', 'FIELD', 1), ('Write', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('NETGEAR', 'ORG'), ('DGN2200', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('NETGEAR', 'ORG', 3), ('DGN2200', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Arm', 'ORG'), ('Mali', 'PRODUCT'), ('GPU Kernel', 'FUNCTION'), ('Information Disclosure', 'FIELD')]
# Tokens [('Arm', 'ORG', 3), ('Mali', 'PRODUCT', 3), ('GPU', 'FUNCTION', 3), ('Kernel', 'FUNCTION', 1), ('Driver', '', 2), ('Information', 'FIELD', 3), ('Disclosure', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Realtek', 'ORG'), ('AP-Router SDK', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Realtek', 'ORG', 3), ('AP', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('Router', 'PRODUCT', 1), ('SDK', 'PRODUCT', 1), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium V8', 'PRODUCT'), ('Out-of-Bounds Write', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('V8', 'PRODUCT', 1), ('Out', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Bounds', 'FIELD', 1), ('Write', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Adobe Type Manager', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Adobe', 'FUNCTION', 3), ('Type', 'FUNCTION', 1), ('Manager', 'FUNCTION', 1), ('Library', '', 2), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Kernel Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Kernel', 'FIELD', 3), ('Privilege', 'FIELD', 1), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('Adaptive Security Appliance', 'PRODUCT'), ('CLI', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('Adaptive', 'PRODUCT', 3), ('Security', 'PRODUCT', 1), ('Appliance', 'PRODUCT', 1), ('(', '', 2), ('ASA', '', 2), (')', '', 2), ('CLI', 'FUNCTION', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Internet Shortcut Files', 'FUNCTION'), ('Security Feature Bypass', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Internet', 'FUNCTION', 3), ('Shortcut', 'FUNCTION', 1), ('Files', 'FUNCTION', 1), ('Security', 'FIELD', 3), ('Feature', 'FIELD', 1), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Memory Initialization', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Initialization', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('QNAP', 'ORG'), ('NAS', 'PRODUCT'), ('File Station', 'FUNCTION'), ('Command Injection', 'FIELD')]
# Tokens [('QNAP', 'ORG', 3), ('NAS', 'PRODUCT', 3), ('File', 'FUNCTION', 3), ('Station', 'FUNCTION', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Red Hat', 'ORG'), ('JBoss', 'PRODUCT'), ('Authentication Bypass', 'FIELD')]
# Tokens [('Red', 'ORG', 3), ('Hat', 'ORG', 1), ('JBoss', 'PRODUCT', 3), ('Authentication', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Zyxel', 'ORG'), ('EMG2926 Routers', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('Zyxel', 'ORG', 3), ('EMG2926', 'PRODUCT', 3), ('Routers', 'PRODUCT', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('EyesOfNetwork', 'ORG'), ('Hard-Coded Credentials', 'FIELD')]
# Tokens [('EyesOfNetwork', 'ORG', 3), ('Use', '', 2), ('of', '', 2), ('Hard', 'FIELD', 3), ('-', 'FIELD', 1), ('Coded', 'FIELD', 1), ('Credentials', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('SmartScreen', 'FUNCTION'), ('Security Feature Bypass', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('SmartScreen', 'FUNCTION', 3), ('Security', 'FIELD', 3), ('Feature', 'FIELD', 1), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('WebKit', 'LIBRARY'), ('Sandbox Escape', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('WebKit', 'LIBRARY', 3), ('Sandbox', 'FIELD', 3), ('Escape', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Acrobat and Reader', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Acrobat', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Reader', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium', 'PRODUCT'), ('Blink', 'LIBRARY'), ('Use-After-Free', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('Blink', 'LIBRARY', 3), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Reader and Acrobat', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Reader', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Acrobat', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Elasticsearch', 'PRODUCT'), ('Groovy Scripting Engine', 'LIBRARY'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Elasticsearch', 'PRODUCT', 3), ('Groovy', 'LIBRARY', 3), ('Scripting', 'LIBRARY', 1), ('Engine', 'LIBRARY', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Kernel Unspecified', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Kernel', 'FIELD', 3), ('Unspecified', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Kernel Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Kernel', 'FIELD', 3), ('Privilege', 'FIELD', 1), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Red Hat', 'ORG'), ('Polkit', 'LIBRARY'), ('Incorrect Authorization', 'FIELD')]
# Tokens [('Red', 'ORG', 3), ('Hat', 'ORG', 1), ('Polkit', 'LIBRARY', 3), ('Incorrect', 'FIELD', 3), ('Authorization', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Edge and Internet Explorer', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Edge', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Internet', 'PRODUCT', 1), ('Explorer', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Exim', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Exim', 'PRODUCT', 3), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Samsung', 'ORG'), ('Mobile Devices', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Samsung', 'ORG', 3), ('Mobile', 'PRODUCT', 3), ('Devices', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Code Aurora', 'ORG'), ('ACDB Audio Driver', 'FUNCTION'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Code', 'ORG', 3), ('Aurora', 'ORG', 1), ('ACDB', 'FUNCTION', 3), ('Audio', 'FUNCTION', 1), ('Driver', 'FUNCTION', 1), ('Stack', '', 2), ('-', '', 2), ('based', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Code Execution', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Code', 'FIELD', 3), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Open Management Infrastructure', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Open', 'FUNCTION', 3), ('Management', 'FUNCTION', 1), ('Infrastructure', 'FUNCTION', 1), ('(', '', 2), ('OMI', '', 2), (')', '', 2), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('VMware', 'ORG'), ('vCenter Server', 'PRODUCT'), ('File Upload', 'FIELD')]
# Tokens [('VMware', 'ORG', 3), ('vCenter', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('File', 'FIELD', 3), ('Upload', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Reader and Acrobat', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Reader', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Acrobat', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Ruby on Rails', 'ORG'), ('Directory Traversal', 'FIELD')]
# Tokens [('Ruby', 'ORG', 3), ('on', 'ORG', 1), ('Rails', 'ORG', 1), ('Directory', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Client Server Runtime Subsystem', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Client', 'FUNCTION', 3), ('Server', 'FUNCTION', 1), ('Runtime', 'FUNCTION', 1), ('Subsystem', 'FUNCTION', 1), ('(', '', 2), ('CSRSS', '', 2), (')', '', 2), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('PHP-CGI', 'LIBRARY'), ('Command Injection', 'FIELD')]
# Tokens [('PHP', 'LIBRARY', 3), ('-', 'LIBRARY', 1), ('CGI', 'LIBRARY', 1), ('OS', '', 2), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Runtime', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Runtime', 'FUNCTION', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Win32k', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Win32k', 'LIBRARY', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Error Reporting Service', 'FUNCTION'), ('Improper Privilege Management', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Error', 'FUNCTION', 3), ('Reporting', 'FUNCTION', 1), ('Service', 'FUNCTION', 1), ('Improper', 'FIELD', 3), ('Privilege', 'FIELD', 1), ('Management', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Netwrix', 'ORG'), ('Auditor', 'PRODUCT'), ('Object Deserialization', 'FIELD')]
# Tokens [('Netwrix', 'ORG', 3), ('Auditor', 'PRODUCT', 3), ('Insecure', '', 2), ('Object', 'FIELD', 3), ('Deserialization', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('ColdFusion', 'PRODUCT'), ('Deserialization of Untrusted Data', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('ColdFusion', 'PRODUCT', 3), ('Deserialization', 'FIELD', 3), ('of', 'FIELD', 1), ('Untrusted', 'FIELD', 1), ('Data', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('QNAP', 'ORG'), ('NAS', 'PRODUCT'), ('File Station', 'FUNCTION'), ('Cross-Site Scripting', 'FIELD')]
# Tokens [('QNAP', 'ORG', 3), ('NAS', 'PRODUCT', 3), ('File', 'FUNCTION', 3), ('Station', 'FUNCTION', 1), ('Cross', 'FIELD', 3), ('-', 'FIELD', 1), ('Site', 'FIELD', 1), ('Scripting', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('LG', 'ORG'), ('N1A1 NAS', 'PRODUCT'), ('Remote Command Execution', 'FIELD')]
# Tokens [('LG', 'ORG', 3), ('N1A1', 'PRODUCT', 3), ('NAS', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Command', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Edge', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Edge', 'PRODUCT', 3), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Arm', 'ORG'), ('Mali', 'PRODUCT'), ('Graphics Processing Unit', 'FUNCTION'), ('Unspecified', 'FIELD')]
# Tokens [('Arm', 'ORG', 3), ('Mali', 'PRODUCT', 3), ('Graphics', 'FUNCTION', 3), ('Processing', 'FUNCTION', 1), ('Unit', 'FUNCTION', 1), ('(', '', 2), ('GPU', '', 2), (')', '', 2), ('Unspecified', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Juniper', 'ORG'), ('Junos OS', 'PRODUCT'), ('PHP', 'FUNCTION'), ('External Variable Modification', 'FIELD')]
# Tokens [('Juniper', 'ORG', 3), ('Junos', 'PRODUCT', 3), ('OS', 'PRODUCT', 1), ('EX', '', 2), ('Series', '', 2), ('PHP', 'FUNCTION', 3), ('External', 'FIELD', 3), ('Variable', 'FIELD', 1), ('Modification', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Mozilla', 'ORG'), ('Firefox', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Mozilla', 'ORG', 3), ('Firefox', 'PRODUCT', 3), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('SAP', 'ORG'), ('NetWeaver', 'PRODUCT'), ('Missing Authentication', 'FIELD')]
# Tokens [('SAP', 'ORG', 3), ('NetWeaver', 'PRODUCT', 3), ('Missing', 'FIELD', 3), ('Authentication', 'FIELD', 1), ('for', '', 2), ('Critical', '', 2), ('Function', '', 2), ('Vulnerability', '', 2)]
# Entities [('Linux Kernel', 'PRODUCT'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Linux', 'PRODUCT', 3), ('Kernel', 'PRODUCT', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Pi-Hole', 'PRODUCT'), ('AdminLTE', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Pi', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('Hole', 'PRODUCT', 1), ('AdminLTE', 'FUNCTION', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('phpMyAdmin', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('phpMyAdmin', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chrome', 'PRODUCT'), ('FreeType', 'LIBRARY'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chrome', 'PRODUCT', 3), ('FreeType', 'LIBRARY', 3), ('Heap', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium V8', 'PRODUCT'), ('Type Confusion', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('V8', 'PRODUCT', 1), ('Type', 'FIELD', 3), ('Confusion', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Oracle', 'ORG'), ('Java SE', 'PRODUCT'), ('Unspecified', 'FIELD')]
# Tokens [('Oracle', 'ORG', 3), ('Java', 'PRODUCT', 3), ('SE', 'PRODUCT', 1), ('Unspecified', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Mark of the Web', 'FUNCTION'), ('Protection Mechanism Failure', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Mark', 'FUNCTION', 3), ('of', 'FUNCTION', 1), ('the', 'FUNCTION', 1), ('Web', 'FUNCTION', 1), ('(', '', 2), ('MOTW', '', 2), (')', '', 2), ('Protection', 'FIELD', 3), ('Mechanism', 'FIELD', 1), ('Failure', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Exchange Server', 'PRODUCT'), ('Validation Key', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Exchange', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Validation', 'FUNCTION', 3), ('Key', 'FUNCTION', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Ivanti', 'ORG'), ('Pulse Connect Secure Collaboration Suite', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Ivanti', 'ORG', 3), ('Pulse', 'PRODUCT', 3), ('Connect', 'PRODUCT', 1), ('Secure', 'PRODUCT', 1), ('Collaboration', 'PRODUCT', 1), ('Suite', 'PRODUCT', 1), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Dahua', 'ORG'), ('IP Camera', 'PRODUCT'), ('Authentication Bypass', 'FIELD')]
# Tokens [('Dahua', 'ORG', 3), ('IP', 'PRODUCT', 3), ('Camera', 'PRODUCT', 1), ('Authentication', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Office', 'PRODUCT'), ('Security Feature Bypass', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Office', 'PRODUCT', 3), ('Security', 'FIELD', 3), ('Feature', 'FIELD', 1), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium V8', 'PRODUCT'), ('Out-of-Bounds Write', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('V8', 'PRODUCT', 1), ('Out', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Bounds', 'FIELD', 1), ('Write', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('D-Link', 'ORG'), ('Multiple Routers', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('D', 'ORG', 3), ('-', 'ORG', 1), ('Link', 'ORG', 1), ('Multiple', 'PRODUCT', 3), ('Routers', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Type Confusion', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Type', 'FIELD', 3), ('Confusion', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Mozilla', 'ORG'), ('Firefox, Firefox ESR, and Thunderbird', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Mozilla', 'ORG', 3), ('Firefox', 'PRODUCT', 3), (',', 'PRODUCT', 1), ('Firefox', 'PRODUCT', 1), ('ESR', 'PRODUCT', 1), (',', 'PRODUCT', 1), ('and', 'PRODUCT', 1), ('Thunderbird', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Zoho', 'ORG'), ('ManageEngine', 'PRODUCT'), ('Multiple Products', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Zoho', 'ORG', 3), ('ManageEngine', 'PRODUCT', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Unraid', 'PRODUCT'), ('Authentication Bypass', 'FIELD')]
# Tokens [('Unraid', 'PRODUCT', 3), ('Authentication', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('MSHTML', 'LIBRARY'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('MSHTML', 'LIBRARY', 3), ('Platform', '', 2), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Oracle', 'ORG'), ('WebLogic Server', 'PRODUCT'), ('Deserialization of Untrusted Data', 'FIELD')]
# Tokens [('Oracle', 'ORG', 3), ('WebLogic', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Deserialization', 'FIELD', 3), ('of', 'FIELD', 1), ('Untrusted', 'FIELD', 1), ('Data', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Error Reporting Manager', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Error', 'FUNCTION', 3), ('Reporting', 'FUNCTION', 1), ('Manager', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Scripting Engine', 'FUNCTION'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Scripting', 'FUNCTION', 3), ('Engine', 'FUNCTION', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Pulse Connect Secure', 'PRODUCT'), ('Code Injection', 'FIELD')]
# Tokens [('Pulse', 'PRODUCT', 3), ('Connect', 'PRODUCT', 1), ('Secure', 'PRODUCT', 1), ('Code', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Office', 'PRODUCT'), ('Object Record Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Office', 'PRODUCT', 3), ('Object', 'FIELD', 3), ('Record', 'FIELD', 1), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apache', 'ORG'), ('Struts', 'LIBRARY'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Apache', 'ORG', 3), ('Struts', 'LIBRARY', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Android Framework', 'PRODUCT'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Android', 'PRODUCT', 3), ('Framework', 'PRODUCT', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Pixel', 'PRODUCT'), ('Out-of-Bounds Write', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Pixel', 'PRODUCT', 3), ('Out', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Bounds', 'FIELD', 1), ('Write', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Roundcube', 'ORG'), ('Webmail', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Roundcube', 'ORG', 3), ('Webmail', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Zimbra', 'ORG'), ('Collaboration', 'PRODUCT'), ('Cross-Site Scripting', 'FIELD')]
# Tokens [('Zimbra', 'ORG', 3), ('Collaboration', 'PRODUCT', 3), ('(', '', 2), ('ZCS', '', 2), (')', '', 2), ('Cross', 'FIELD', 3), ('-', 'FIELD', 1), ('Site', 'FIELD', 1), ('Scripting', 'FIELD', 1), ('(', '', 2), ('XSS', '', 2), (')', '', 2), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Common Log File System', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Common', 'FUNCTION', 3), ('Log', 'FUNCTION', 1), ('File', 'FUNCTION', 1), ('System', 'FUNCTION', 1), ('(', '', 2), ('CLFS', '', 2), (')', '', 2), ('Driver', '', 2), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Liferay', 'ORG'), ('Portal', 'PRODUCT'), ('Deserialization of Untrusted Data', 'FIELD')]
# Tokens [('Liferay', 'ORG', 3), ('Portal', 'PRODUCT', 3), ('Deserialization', 'FIELD', 3), ('of', 'FIELD', 1), ('Untrusted', 'FIELD', 1), ('Data', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Excel', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Excel', 'PRODUCT', 3), ('Featheader', '', 2), ('Record', '', 2), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('TerraMaster', 'ORG'), ('OS', 'PRODUCT'), ('Remote Command Execution', 'FIELD')]
# Tokens [('TerraMaster', 'ORG', 3), ('OS', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Command', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Roundcube', 'ORG'), ('Webmail', 'PRODUCT'), ('Cross-Site Scripting', 'FIELD')]
# Tokens [('Roundcube', 'ORG', 3), ('Webmail', 'PRODUCT', 3), ('Persistent', '', 2), ('Cross', 'FIELD', 3), ('-', 'FIELD', 1), ('Site', 'FIELD', 1), ('Scripting', 'FIELD', 1), ('(', '', 2), ('XSS', '', 2), (')', '', 2), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('IOS and IOS XE Software', 'PRODUCT'), ('SNMP', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('IOS', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('IOS', 'PRODUCT', 1), ('XE', 'PRODUCT', 1), ('Software', 'PRODUCT', 1), ('SNMP', 'FUNCTION', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Word', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Word', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Progress', 'ORG'), ('Telerik UI', 'PRODUCT'), ('ASP.NET AJAX', 'LIBRARY'), ('Deserialization of Untrusted Data', 'FIELD')]
# Tokens [('Progress', 'ORG', 3), ('Telerik', 'PRODUCT', 3), ('UI', 'PRODUCT', 1), ('for', '', 2), ('ASP.NET', 'LIBRARY', 3), ('AJAX', 'LIBRARY', 1), ('Deserialization', 'FIELD', 3), ('of', 'FIELD', 1), ('Untrusted', 'FIELD', 1), ('Data', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium V8', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('V8', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Reader and Acrobat', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Reader', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('Acrobat', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Win32k', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Win32k', 'LIBRARY', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows Installer', 'PRODUCT'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Installer', 'PRODUCT', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Fortinet', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Authentication Bypass', 'FIELD')]
# Tokens [('Fortinet', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Authentication', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Atlassian', 'ORG'), ('Confluence Data Center and Server', 'PRODUCT'), ('Broken Access Control', 'FIELD')]
# Tokens [('Atlassian', 'ORG', 3), ('Confluence', 'PRODUCT', 3), ('Data', 'PRODUCT', 1), ('Center', 'PRODUCT', 1), ('and', 'PRODUCT', 1), ('Server', 'PRODUCT', 1), ('Broken', 'FIELD', 3), ('Access', 'FIELD', 1), ('Control', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('GIGABYTE', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Unspecified', 'FIELD')]
# Tokens [('GIGABYTE', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Unspecified', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Citrix', 'ORG'), ('Content Collaboration', 'PRODUCT'), ('ShareFile', 'FUNCTION'), ('Improper Access Control', 'FIELD')]
# Tokens [('Citrix', 'ORG', 3), ('Content', 'PRODUCT', 3), ('Collaboration', 'PRODUCT', 1), ('ShareFile', 'FUNCTION', 3), ('Improper', 'FIELD', 3), ('Access', 'FIELD', 1), ('Control', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('F5', 'ORG'), ('BIG-IP', 'PRODUCT'), ('Missing Authentication', 'FIELD')]
# Tokens [('F5', 'ORG', 3), ('BIG', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('IP', 'PRODUCT', 1), ('Missing', 'FIELD', 3), ('Authentication', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('IOS and IOS XE', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('IOS', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('IOS', 'PRODUCT', 1), ('XE', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Active Directory', 'PRODUCT'), ('Domain Services', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Active', 'PRODUCT', 3), ('Directory', 'PRODUCT', 1), ('Domain', 'FUNCTION', 3), ('Services', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('WebKit', 'LIBRARY'), ('Integer Overflow', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('WebKit', 'LIBRARY', 3), ('Integer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Tenda', 'ORG'), ('AC1900 Router', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Tenda', 'ORG', 3), ('AC1900', 'PRODUCT', 3), ('Router', 'PRODUCT', 1), ('AC15', '', 2), ('Model', '', 2), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Word', 'PRODUCT'), ('Malformed Object Pointer', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Word', 'PRODUCT', 3), ('Malformed', 'FIELD', 3), ('Object', 'FIELD', 1), ('Pointer', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Print Spooler', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Print', 'FUNCTION', 3), ('Spooler', 'FUNCTION', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('IOS Software', 'PRODUCT'), ('Cisco', 'ORG'), ('Industrial Ethernet Switches', 'PRODUCT'), ('PROFINET', 'FUNCTION'), ('Denial-of-Service', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('IOS', 'PRODUCT', 3), ('Software', 'PRODUCT', 1), ('for', '', 2), ('Cisco', 'ORG', 3), ('Industrial', 'PRODUCT', 3), ('Ethernet', 'PRODUCT', 1), ('Switches', 'PRODUCT', 1), ('PROFINET', 'FUNCTION', 3), ('Denial', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Service', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Common Log File System', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Common', 'FUNCTION', 3), ('Log', 'FUNCTION', 1), ('File', 'FUNCTION', 1), ('System', 'FUNCTION', 1), ('(', '', 2), ('CLFS', '', 2), (')', '', 2), ('Driver', '', 2), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('IBM', 'ORG'), ('Data Risk Manager', 'PRODUCT'), ('Directory Traversal', 'FIELD')]
# Tokens [('IBM', 'ORG', 3), ('Data', 'PRODUCT', 3), ('Risk', 'PRODUCT', 1), ('Manager', 'PRODUCT', 1), ('Directory', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Office Publisher', 'PRODUCT'), ('Security Feature Bypass', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Office', 'PRODUCT', 3), ('Publisher', 'PRODUCT', 1), ('Security', 'FIELD', 3), ('Feature', 'FIELD', 1), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Exchange Server', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Exchange', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Flash Player', 'PRODUCT'), ('Arbitrary Code Execution', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('Arbitrary', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Trend Micro', 'ORG'), ('OfficeScan', 'PRODUCT'), ('Directory Traversal', 'FIELD')]
# Tokens [('Trend', 'ORG', 3), ('Micro', 'ORG', 1), ('OfficeScan', 'PRODUCT', 3), ('Directory', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Adobe', 'ORG'), ('Flash Player', 'PRODUCT'), ('Dereferenced Pointer', 'FIELD')]
# Tokens [('Adobe', 'ORG', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('Dereferenced', 'FIELD', 3), ('Pointer', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('WhatsApp', 'PRODUCT'), ('Cross-Site Scripting', 'FIELD')]
# Tokens [('WhatsApp', 'PRODUCT', 3), ('Cross', 'FIELD', 3), ('-', 'FIELD', 1), ('Site', 'FIELD', 1), ('Scripting', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Schneider Electric', 'ORG'), ('U.motion Builder', 'PRODUCT'), ('SQL Injection', 'FIELD')]
# Tokens [('Schneider', 'ORG', 3), ('Electric', 'ORG', 1), ('U.motion', 'PRODUCT', 3), ('Builder', 'PRODUCT', 1), ('SQL', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Veeam', 'ORG'), ('Backup & Replication', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Veeam', 'ORG', 3), ('Backup', 'PRODUCT', 3), ('&', 'PRODUCT', 1), ('Replication', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('Kernel Privilege Escalation', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('Kernel', 'FIELD', 3), ('Privilege', 'FIELD', 1), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Mozilla', 'ORG'), ('Firefox And Thunderbird', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# ...
# Tokens [('Microsoft', 'ORG', 3), ('Win32k', 'LIBRARY', 3), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Print Spooler', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Print', 'FUNCTION', 3), ('Spooler', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Fortinet', 'ORG'), ('FortiOS', 'PRODUCT'), ('SSL VPN', 'FUNCTION'), ('Path Traversal', 'FIELD')]
# Tokens [('Fortinet', 'ORG', 3), ('FortiOS', 'PRODUCT', 3), ('SSL', 'FUNCTION', 3), ('VPN', 'FUNCTION', 1), ('Path', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium', 'PRODUCT'), ('Blink', 'LIBRARY'), ('Use-After-Free', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('Blink', 'LIBRARY', 3), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('WordPress', 'PRODUCT'), ('Snap Creek', 'ORG'), ('Duplicator Plugin', 'FUNCTION'), ('File Download', 'FIELD')]
# Tokens [('WordPress', 'PRODUCT', 3), ('Snap', 'ORG', 3), ('Creek', 'ORG', 1), ('Duplicator', 'FUNCTION', 3), ('Plugin', 'FUNCTION', 1), ('File', 'FIELD', 3), ('Download', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('DirectX Graphics Kernel', 'LIBRARY'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('DirectX', 'LIBRARY', 3), ('Graphics', 'LIBRARY', 1), ('Kernel', 'LIBRARY', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('PowerPoint', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('PowerPoint', 'PRODUCT', 3), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('User Profile Service', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('User', 'FUNCTION', 3), ('Profile', 'FUNCTION', 1), ('Service', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('iOS and iPadOS', 'PRODUCT'), ('Out-of-Bounds Write', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('iOS', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('iPadOS', 'PRODUCT', 1), ('Out', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Bounds', 'FIELD', 1), ('Write', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Delta Electronics', 'ORG'), ('DOPSoft 2', 'PRODUCT'), ('Improper Input Validation', 'FIELD')]
# Tokens [('Delta', 'ORG', 3), ('Electronics', 'ORG', 1), ('DOPSoft', 'PRODUCT', 3), ('2', 'PRODUCT', 1), ('Improper', 'FIELD', 3), ('Input', 'FIELD', 1), ('Validation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apache', 'ORG'), ('Struts 2', 'LIBRARY'), ('Improper Input Validation', 'FIELD')]
# Tokens [('Apache', 'ORG', 3), ('Struts', 'LIBRARY', 3), ('2', 'LIBRARY', 1), ('Improper', 'FIELD', 3), ('Input', 'FIELD', 1), ('Validation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('LSA', 'FUNCTION'), ('Spoofing', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('LSA', 'FUNCTION', 3), ('Spoofing', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Redis Server', 'PRODUCT'), ('Sandbox Escape', 'FIELD')]
# Tokens [('Debian', '', 2), ('-', '', 2), ('specific', '', 2), ('Redis', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Lua', '', 2), ('Sandbox', 'FIELD', 3), ('Escape', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Oracle', 'ORG'), ('VirtualBox', 'PRODUCT'), ('Insufficient Input Validation', 'FIELD')]
# Tokens [('Oracle', 'ORG', 3), ('VirtualBox', 'PRODUCT', 3), ('Insufficient', 'FIELD', 3), ('Input', 'FIELD', 1), ('Validation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('RARLAB', 'ORG'), ('WinRAR', 'PRODUCT'), ('Code Execution', 'FIELD')]
# Tokens [('RARLAB', 'ORG', 3), ('WinRAR', 'PRODUCT', 3), ('Code', 'FIELD', 3), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Adobe Font Manager Library', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Adobe', 'FUNCTION', 3), ('Font', 'FUNCTION', 1), ('Manager', 'FUNCTION', 1), ('Library', 'FUNCTION', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('QNAP', 'ORG'), ('Photo Station', 'FUNCTION'), ('Improper Access Control', 'FIELD')]
# Tokens [('QNAP', 'ORG', 3), ('Photo', 'FUNCTION', 3), ('Station', 'FUNCTION', 1), ('Improper', 'FIELD', 3), ('Access', 'FIELD', 1), ('Control', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Scripting Engine', 'FUNCTION'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Scripting', 'FUNCTION', 3), ('Engine', 'FUNCTION', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Qualcomm', 'ORG'), ('Multiple Chipsets', 'PRODUCT'), ('Use-After-Free', 'FIELD')]
# Tokens [('Qualcomm', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Chipsets', 'PRODUCT', 1), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('XStream', 'LIBRARY'), ('Remote Code Execution', 'FIELD')]
# Tokens [('XStream', 'LIBRARY', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Internet Explorer', 'PRODUCT'), ('Scripting Engine', 'FUNCTION'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Internet', 'PRODUCT', 3), ('Explorer', 'PRODUCT', 1), ('Scripting', 'FUNCTION', 3), ('Engine', 'FUNCTION', 1), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('CryptoAPI', 'LIBRARY'), ('Spoofing', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('CryptoAPI', 'LIBRARY', 3), ('Spoofing', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Zoho', 'ORG'), ('ManageEngine', 'PRODUCT'), ('ADSelfService Plus', 'FUNCTION'), ('Authentication Bypass', 'FIELD')]
# Tokens [('Zoho', 'ORG', 3), ('ManageEngine', 'PRODUCT', 3), ('ADSelfService', 'FUNCTION', 3), ('Plus', 'FUNCTION', 1), ('Authentication', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('WebRTC', 'LIBRARY'), ('Buffer Overflow', 'FIELD')]
# Tokens [('WebRTC', 'LIBRARY', 3), ('Heap', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('IOS Software', 'PRODUCT'), ('Network Address Translation', 'FUNCTION'), ('Denial-of-Service', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('IOS', 'PRODUCT', 3), ('Software', 'PRODUCT', 1), ('Network', 'FUNCTION', 3), ('Address', 'FUNCTION', 1), ('Translation', 'FUNCTION', 1), ('Denial', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Service', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('WebKit', 'LIBRARY'), ('Use-After-Free', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('WebKit', 'LIBRARY', 3), ('Use', 'FIELD', 3), ('-', 'FIELD', 1), ('After', 'FIELD', 1), ('-', 'FIELD', 1), ('Free', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('AnyConnect Secure Mobility Client for Windows', 'PRODUCT'), ('DLL Hijacking', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('AnyConnect', 'PRODUCT', 3), ('Secure', 'PRODUCT', 1), ('Mobility', 'PRODUCT', 1), ('Client', 'PRODUCT', 1), ('for', 'PRODUCT', 1), ('Windows', 'PRODUCT', 1), ('DLL', 'FIELD', 3), ('Hijacking', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Arcserve', 'PRODUCT'), ('Unified Data Protection', 'FUNCTION'), ('Directory Traversal', 'FIELD')]
# Tokens [('Arcserve', 'PRODUCT', 3), ('Unified', 'FUNCTION', 3), ('Data', 'FUNCTION', 1), ('Protection', 'FUNCTION', 1), ('(', '', 2), ('UDP', '', 2), (')', '', 2), ('Directory', 'FIELD', 3), ('Traversal', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('HTTP/2', 'LIBRARY'), ('Rapid Reset Attack', 'FIELD')]
# Tokens [('HTTP/2', 'LIBRARY', 3), ('Rapid', 'FIELD', 3), ('Reset', 'FIELD', 1), ('Attack', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('SolarWinds', 'ORG'), ('Virtualization Manager', 'PRODUCT'), ('Privilege Escalation', 'FIELD')]
# Tokens [('SolarWinds', 'ORG', 3), ('Virtualization', 'PRODUCT', 3), ('Manager', 'PRODUCT', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apache', 'ORG'), ('Shiro', 'LIBRARY'), ('Code Execution', 'FIELD')]
# Tokens [('Apache', 'ORG', 3), ('Shiro', 'LIBRARY', 3), ('Code', 'FIELD', 3), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium V8', 'PRODUCT'), ('Type Confusion', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('V8', 'PRODUCT', 1), ('Type', 'FIELD', 3), ('Confusion', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Fortinet', 'ORG'), ('FortiOS', 'PRODUCT'), ('Arbitrary File Download', 'FIELD')]
# Tokens [('Fortinet', 'ORG', 3), ('FortiOS', 'PRODUCT', 3), ('Arbitrary', 'FIELD', 3), ('File', 'FIELD', 1), ('Download', 'FIELD', 1)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('Error Reporting Service', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('Error', 'FUNCTION', 3), ('Reporting', 'FUNCTION', 1), ('Service', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('NX-OS', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('NX', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('OS', 'PRODUCT', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Netis', 'ORG'), ('WF2419 Devices', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Netis', 'ORG', 3), ('WF2419', 'PRODUCT', 3), ('Devices', 'PRODUCT', 1), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('dotCMS', 'PRODUCT'), ('Unrestricted Upload of File', 'FIELD')]
# Tokens [('dotCMS', 'PRODUCT', 3), ('Unrestricted', 'FIELD', 3), ('Upload', 'FIELD', 1), ('of', 'FIELD', 1), ('File', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Windows', 'PRODUCT'), ('AppX Installer', 'FUNCTION'), ('Spoofing', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Windows', 'PRODUCT', 3), ('AppX', 'FUNCTION', 3), ('Installer', 'FUNCTION', 1), ('Spoofing', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Google', 'ORG'), ('Chromium', 'PRODUCT'), ('PopupBlocker', 'FUNCTION'), ('Security Bypass', 'FIELD')]
# Tokens [('Google', 'ORG', 3), ('Chromium', 'PRODUCT', 3), ('PopupBlocker', 'FUNCTION', 3), ('Security', 'FIELD', 3), ('Bypass', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('IOS and IOS XE Software', 'PRODUCT'), ('SNMP', 'FUNCTION'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('IOS', 'PRODUCT', 3), ('and', 'PRODUCT', 1), ('IOS', 'PRODUCT', 1), ('XE', 'PRODUCT', 1), ('Software', 'PRODUCT', 1), ('SNMP', 'FUNCTION', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('PHP-CGI', 'LIBRARY'), ('Query String Parameter', 'FIELD')]
# Tokens [('PHP', 'LIBRARY', 3), ('-', 'LIBRARY', 1), ('CGI', 'LIBRARY', 1), ('Query', 'FIELD', 3), ('String', 'FIELD', 1), ('Parameter', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('ownCloud', 'PRODUCT'), ('graphapi', 'LIBRARY'), ('Information Disclosure', 'FIELD')]
# Tokens [('ownCloud', 'PRODUCT', 3), ('graphapi', 'LIBRARY', 3), ('Information', 'FIELD', 3), ('Disclosure', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('GNU', 'ORG'), ('Bourne-Again Shell', 'PRODUCT'), ('Arbitrary Code Execution', 'FIELD')]
# Tokens [('GNU', 'ORG', 3), ('Bourne', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('Again', 'PRODUCT', 1), ('Shell', 'PRODUCT', 1), ('(', '', 2), ('Bash', '', 2), (')', '', 2), ('Arbitrary', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Oracle', 'ORG'), ('Fusion Middleware', 'PRODUCT'), ('Unspecified', 'FIELD')]
# Tokens [('Oracle', 'ORG', 3), ('Fusion', 'PRODUCT', 3), ('Middleware', 'PRODUCT', 1), ('Unspecified', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Microsoft', 'ORG'), ('Office', 'PRODUCT'), ('Memory Corruption', 'FIELD')]
# Tokens [('Microsoft', 'ORG', 3), ('Office', 'PRODUCT', 3), ('Memory', 'FIELD', 3), ('Corruption', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Oracle', 'ORG'), ('WebLogic Server', 'PRODUCT'), ('Unspecified', 'FIELD')]
# Tokens [('Oracle', 'ORG', 3), ('WebLogic', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Unspecified', 'FIELD', 3), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('Small Business RV Series Routers', 'PRODUCT'), ('Buffer Overflow', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('Small', 'PRODUCT', 3), ('Business', 'PRODUCT', 1), ('RV', 'PRODUCT', 1), ('Series', 'PRODUCT', 1), ('Routers', 'PRODUCT', 1), ('Stack', '', 2), ('-', '', 2), ('based', '', 2), ('Buffer', 'FIELD', 3), ('Overflow', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Cisco', 'ORG'), ('IOS XE', 'PRODUCT'), ('Web UI', 'FUNCTION'), ('Privilege Escalation', 'FIELD')]
# Tokens [('Cisco', 'ORG', 3), ('IOS', 'PRODUCT', 3), ('XE', 'PRODUCT', 1), ('Web', 'FUNCTION', 3), ('UI', 'FUNCTION', 1), ('Privilege', 'FIELD', 3), ('Escalation', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Treck TCP/IP stack', 'LIBRARY'), ('Out-of-Bounds Read', 'FIELD')]
# Tokens [('Treck', 'LIBRARY', 3), ('TCP', 'LIBRARY', 1), ('/', 'LIBRARY', 1), ('IP', 'LIBRARY', 1), ('stack', 'LIBRARY', 1), ('Out', 'FIELD', 3), ('-', 'FIELD', 1), ('of', 'FIELD', 1), ('-', 'FIELD', 1), ('Bounds', 'FIELD', 1), ('Read', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('IBM', 'ORG'), ('WebSphere Application Server and Server Hypervisor', 'PRODUCT'), ('Code Injection', 'FIELD')]
# Tokens [('IBM', 'ORG', 3), ('WebSphere', 'PRODUCT', 3), ('Application', 'PRODUCT', 1), ('Server', 'PRODUCT', 1), ('and', 'PRODUCT', 1), ('Server', 'PRODUCT', 1), ('Hypervisor', 'PRODUCT', 1), ('Edition', '', 2), ('Code', 'FIELD', 3), ('Injection', 'FIELD', 1), ('.', '', 2)]
# Entities [('VMware', 'ORG'), ('vCenter Server', 'PRODUCT'), ('Improper Access Control', 'FIELD')]
# Tokens [('VMware', 'ORG', 3), ('vCenter', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('Improper', 'FIELD', 3), ('Access', 'FIELD', 1), ('Control', 'FIELD', 1)]
# Entities [('Sophos', 'ORG'), ('Firewall', 'PRODUCT'), ('Code Injection', 'FIELD')]
# Tokens [('Sophos', 'ORG', 3), ('Firewall', 'PRODUCT', 3), ('Code', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('Apple', 'ORG'), ('Multiple Products', 'PRODUCT'), ('WebKit', 'LIBRARY'), ('Code Execution', 'FIELD')]
# Tokens [('Apple', 'ORG', 3), ('Multiple', 'PRODUCT', 3), ('Products', 'PRODUCT', 1), ('WebKit', 'LIBRARY', 3), ('Code', 'FIELD', 3), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('OSGeo', 'ORG'), ('GeoServer', 'PRODUCT'), ('JAI-EXT', 'LIBRARY'), ('Code Injection', 'FIELD')]
# Tokens [('OSGeo', 'ORG', 3), ('GeoServer', 'PRODUCT', 3), ('JAI', 'LIBRARY', 3), ('-', 'LIBRARY', 1), ('EXT', 'LIBRARY', 1), ('Code', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]

# %% [markdown]
# ### Save the cusom NER model

# %%
output_dir= os.path.abspath(os.getcwd())
nlp.to_disk(output_dir)
print("Saved model to", output_dir)
# Out:
# Saved model to /Users/dj/Desktop/Capstone/Capstone

# %% [markdown]
# ### Test the saved custom model

# %%
print("Loading from", output_dir)
nlp2 = spacy.load(output_dir)
for annotations in training_data["annotations"][3:5]:
    doc = nlp2(annotations['text'])
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Loading from /Users/dj/Desktop/Capstone/Capstone
# Entities [('Primetek', 'ORG'), ('Primefaces', 'PRODUCT'), ('Remote Code Execution', 'FIELD')]
# Tokens [('Primetek', 'ORG', 3), ('Primefaces', 'PRODUCT', 3), ('Remote', 'FIELD', 3), ('Code', 'FIELD', 1), ('Execution', 'FIELD', 1), ('Vulnerability', '', 2)]
# Entities [('SIMalliance', 'ORG'), ('Toolbox Browser', 'PRODUCT'), ('Command Injection', 'FIELD')]
# Tokens [('SIMalliance', 'ORG', 3), ('Toolbox', 'PRODUCT', 3), ('Browser', 'PRODUCT', 1), ('Command', 'FIELD', 3), ('Injection', 'FIELD', 1), ('Vulnerability', '', 2)]

# %%
file = open('text2.txt')
text = file.read()
file.close()
nlp2 = spacy.load(output_dir)
doc = nlp2(text)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chromium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Skia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LIBRARY</span>
# </mark>
#  contains an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     integer overflow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#  vulnerability that allows a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     remote attacker, who has compromised the renderer process, to
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     potentially perform a sandbox escape via a crafted
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTML page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
# . This vulnerability
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     affects Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chrome and ChromeOS, Android, Flutter, and possibly other products
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RealTek Jungle SDK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  contains multiple
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     memory corruption
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#  vulnerabilities
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     which can allow an attacker to perform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     remote code execution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux Kernel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FUNCTION</span>
# </mark>
#  contains a race condition vulnerability
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     within the n_tty_write
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#  function that allows
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     local users
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FUNCTION</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     to cause a
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     denial-of-service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FIELD</span>
# </mark>
#  (DoS) or gain
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     privileges
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     via read and write operations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     with
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FUNCTION</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     long strings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FUNCTION</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Primetek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Primefaces is vulnerable to a weak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %%
import json
 
with open('annotations.json', 'r') as f:
    data = json.load(f)
    
print(data['annotations'][0])
data['classes']
## Create empty model
training_data = data.copy()
training_data['classes'] = data['classes']
training_data['annotations'] = []
for text, annotation in data['annotations']:
    try:
        if text!="" and len(annotation['entities']) > 0:
            temp_dict = {}
            temp_dict['text'] = text
            temp_dict['entities'] = []
            for ent in annotation['entities']:
                start = ent[0]
                end = ent[1]
                label = ent[2].upper()
                temp_dict['entities'].append((start, end, label))
        training_data['annotations'].append(temp_dict)
    except:
        pass
print(training_data)
### Configuration variables
modelSpacy = None
n_iter=100
### Load the model
if modelSpacy is not None:
    nlp = spacy.load(modelSpacy)  
    print("Loaded model '%s'" % modelSpacy)
else:
    nlp = spacy.blank('en')  
    print("Created blank 'en' model")
### Set up pipeline
if 'ner' not in nlp.pipe_names:
    ner = nlp.add_pipe('ner')
else:
    ner = nlp.get_pipe('ner')
### Train the NER model
#getting all the entities
for annotations in training_data["annotations"]:
    for ent in annotations['entities']:
        ner.add_label(ent[2])
        
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    for itn in range(n_iter):
        losses = {}
        for text, annotations in tqdm(data["annotations"]):
            try:
                if text!="":
                    example = Example.from_dict(nlp.make_doc(text), annotations)
                    #Update the model
                    nlp.update(
                        [example],  
                        drop=0.5,  
                        sgd=optimizer,
                        losses=losses)
            except:
                pass
        print(losses)

### Test the trained model
for annotations in training_data["annotations"]:
    doc = nlp(annotations['text'])
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
### Save the cusom NER model
output_dir= os.path.abspath(os.getcwd())
nlp.to_disk(output_dir)
print("Saved model to", output_dir) 
### Test the saved custom model
print("Loading from", output_dir)
nlp2 = spacy.load(output_dir)
for annotations in training_data["annotations"][3:5]:
    doc = nlp2(annotations['text'])
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
file = open('text2.txt')
text = file.read()
file.close()
nlp2 = spacy.load(output_dir)
doc = nlp2(text)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# ['Microsoft Office Publisher contains a security feature bypass vulnerability that allows for a local, authenticated attack on a targeted system.', {'entities': [[0, 9, 'VENDOR'], [10, 26, 'PRODUCT'], [38, 61, 'VULNERABILITY NAME'], [94, 121, 'ACTOR'], [127, 142, 'MODULE']]}]
# {'classes': ['VENDOR', 'PRODUCT', 'FEATURE', 'ACTOR', 'EXPLOIT', 'MODULE', 'VULNERABILITY NAME'], 'annotations': [{'text': 'Microsoft Office Publisher contains a security feature bypass vulnerability that allows for a local, authenticated attack on a targeted system.', 'entities': [(0, 9, 'VENDOR'), (10, 26, 'PRODUCT'), (38, 61, 'VULNERABILITY NAME'), (94, 121, 'ACTOR'), (127, 142, 'MODULE')]}, {'text': 'Microsoft Exchange Server contains an unspecified vulnerability that allows for remote code execution. This vulnerability is part of the ProxyLogon exploit chain.', 'entities': [(0, 9, 'VENDOR'), (10, 25, 'PRODUCT'), (38, 49, 'VULNERABILITY NAME'), (80, 102, 'EXPLOIT'), (137, 147, 'EXPLOIT')]}, {'text': 'Unspecified vulnerability in Adobe Flash Player allows remote attackers to execute arbitrary code or cause a denial of service via crafted SWF content.', 'entities': [(0, 11, 'VULNERABILITY NAME'), (29, 34, 'VENDOR'), (35, 47, 'PRODUCT'), (55, 71, 'ACTOR'), (75, 97, 'EXPLOIT'), (109, 126, 'EXPLOIT'), (131, 150, 'MODULE')]}, {'text': 'Trend Micro OfficeScan contains a directory traversal vulnerability by extracting files from a zip file to a specific folder on the OfficeScan server, leading to remote code execution.', 'entities': [(0, 11, 'VENDOR'), (12, 22, 'PRODUCT'), (34, 53, 'VULNERABILITY NAME'), (132, 142, 'PRODUCT'), (162, 183, 'EXPLOIT')]}, {'text': 'Adobe Flash Player has a vulnerability in the way it handles a dereferenced memory pointer which could lead to code execution.', 'entities': [(0, 5, 'VENDOR'), (6, 18, 'PRODUCT'), (63, 90, 'MODULE'), (111, 125, 'EXPLOIT')]}, {'text': 'A vulnerability in WhatsApp Desktop when paired with WhatsApp for iPhone allows cross-site scripting and local file reading.', 'entities': [(19, 27, 'VENDOR'), (28, 35, 'PRODUCT'), (53, 61, 'VENDOR'), (66, 72, 'PRODUCT'), (80, 100, 'EXPLOIT'), (105, 123, 'EXPLOIT')]}, {'text': 'A SQL Injection vulnerability exists in U.motion Builder software which could cause unwanted code execution when an improper set of characters is entered.', 'entities': [(2, 15, 'VULNERABILITY NAME'), (40, 48, 'VENDOR'), (49, 65, 'PRODUCT'), (84, 107, 'EXPLOIT')]}, {'text': 'The Veeam Distribution Service in the Backup & Replication application allows unauthenticated users to access internal API functions. A remote attacker can send input to the internal API which may lead to uploading and executing of malicious code.', 'entities': [(4, 9, 'VENDOR'), (10, 30, 'PRODUCT'), (38, 58, 'FEATURE'), (78, 99, 'ACTOR'), (103, 133, 'EXPLOIT'), (136, 151, 'ACTOR'), (174, 186, 'MODULE'), (205, 246, 'EXPLOIT')]}, {'text': 'Apple iOS, iPadOS, macOS, and watchOS contain an unspecified vulnerability that allows for local privilege escalation.', 'entities': [(0, 5, 'VENDOR'), (6, 9, 'PRODUCT'), (11, 17, 'PRODUCT'), (19, 24, 'PRODUCT'), (30, 37, 'PRODUCT'), (49, 60, 'VULNERABILITY NAME'), (91, 118, 'EXPLOIT')]}, {'text': 'Mozilla Firefox and Thunderbird contain a race condition vulnerability when running the nsDocShell destructor under certain conditions. The race condition creates a use-after-free vulnerability, causing unspecified impacts.', 'entities': [(0, 7, 'VENDOR'), (8, 15, 'PRODUCT'), (20, 31, 'PRODUCT'), (42, 56, 'VULNERABILITY NAME'), (88, 109, 'FEATURE'), (165, 179, 'VULNERABILITY NAME'), (203, 222, 'EXPLOIT')]}, {'text': 'A cross-site scripting vulnerability affecting QNAP NAS File Station could allow remote attackers to inject malicious code.', 'entities': [(2, 22, 'VULNERABILITY NAME'), (47, 51, 'VENDOR'), (52, 68, 'PRODUCT'), (81, 97, 'ACTOR'), (101, 122, 'EXPLOIT')]}, {'text': 'Drupal Core contains a remote code execution vulnerability that could allow an attacker to exploit multiple attack vectors on a Drupal site, resulting in complete site compromise.', 'entities': [(0, 6, 'VENDOR'), (7, 11, 'PRODUCT'), (23, 44, 'VULNERABILITY NAME'), (79, 87, 'ACTOR'), (154, 178, 'EXPLOIT')]}, {'text': 'Google Chromium WebP contains a heap-based buffer overflow vulnerability that allo ...
# Created blank 'en' model
# 100%|██████████| 31/31 [00:00<00:00, 80.35it/s]
# {'ner': 511.01224369685497}
# 100%|██████████| 31/31 [00:00<00:00, 72.73it/s]
# {'ner': 324.8892041780855}
# 100%|██████████| 31/31 [00:00<00:00, 82.68it/s]
# {'ner': 298.92395720276704}
# 100%|██████████| 31/31 [00:00<00:00, 82.23it/s]
# {'ner': 274.04506498165756}
# 100%|██████████| 31/31 [00:00<00:00, 82.53it/s]
# {'ner': 378.2655463790519}
# 100%|██████████| 31/31 [00:00<00:00, 83.67it/s]
# {'ner': 267.0504632670235}
# 100%|██████████| 31/31 [00:00<00:00, 77.05it/s]
# {'ner': 278.77798714209223}
# 100%|██████████| 31/31 [00:00<00:00, 77.87it/s]
# {'ner': 265.8112647497519}
# 100%|██████████| 31/31 [00:00<00:00, 83.28it/s]
# {'ner': 250.84692137300118}
# 100%|██████████| 31/31 [00:00<00:00, 82.96it/s]
# {'ner': 304.8193462071319}
# 100%|██████████| 31/31 [00:00<00:00, 77.68it/s]
# {'ner': 269.331589568524}
# 100%|██████████| 31/31 [00:00<00:00, 76.40it/s]
# {'ner': 245.6555304862586}
# 100%|██████████| 31/31 [00:00<00:00, 83.38it/s]
# {'ner': 265.6732646022625}
# 100%|██████████| 31/31 [00:00<00:00, 82.53it/s]
# {'ner': 223.8592767043765}
# 100%|██████████| 31/31 [00:00<00:00, 82.83it/s]
# {'ner': 271.41076546216493}
# 100%|██████████| 31/31 [00:00<00:00, 83.04it/s]
# {'ner': 221.08538702611978}
# 100%|██████████| 31/31 [00:00<00:00, 83.15it/s]
# {'ner': 226.51630779637736}
# 100%|██████████| 31/31 [00:00<00:00, 83.02it/s]
# {'ner': 219.84219469043984}
# 100%|██████████| 31/31 [00:00<00:00, 83.02it/s]
# {'ner': 212.20535975810955}
# 100%|██████████| 31/31 [00:00<00:00, 77.87it/s]
# {'ner': 217.82540056722794}
# 100%|██████████| 31/31 [00:00<00:00, 82.66it/s]
# {'ner': 210.18899472163378}
# 100%|██████████| 31/31 [00:00<00:00, 83.26it/s]
# {'ner': 204.93369287984441}
# 100%|██████████| 31/31 [00:00<00:00, 83.27it/s]
# {'ner': 186.16770926909095}
# 100%|██████████| 31/31 [00:00<00:00, 83.24it/s]
# {'ner': 171.25698772988616}
# 100%|██████████| 31/31 [00:00<00:00, 83.30it/s]
# {'ner': 157.40536022031662}
# 100%|██████████| 31/31 [00:00<00:00, 82.43it/s]
# {'ner': 188.3831356538368}
# 100%|██████████| 31/31 [00:00<00:00, 82.65it/s]
# {'ner': 148.3632485609029}
# 100%|██████████| 31/31 [00:00<00:00, 82.74it/s]
# {'ner': 156.1414489213178}
# 100%|██████████| 31/31 [00:00<00:00, 77.99it/s]
# {'ner': 172.61081754092942}
# 100%|██████████| 31/31 [00:00<00:00, 82.35it/s]
# {'ner': 169.14676880301766}
# 100%|██████████| 31/31 [00:00<00:00, 82.34it/s]
# {'ner': 145.49253001636836}
# 100%|██████████| 31/31 [00:00<00:00, 82.50it/s]
# {'ner': 142.47594444654774}
# 100%|██████████| 31/31 [00:00<00:00, 82.88it/s]
# {'ner': 132.42227125293903}
# 100%|██████████| 31/31 [00:00<00:00, 83.05it/s]
# {'ner': 148.677973093293}
# 100%|██████████| 31/31 [00:00<00:00, 82.72it/s]
# {'ner': 142.843559083917}
# 100%|██████████| 31/31 [00:00<00:00, 82.45it/s]
# {'ner': 135.87309507032404}
# 100%|██████████| 31/31 [00:00<00:00, 82.50it/s]
# {'ner': 152.38327804621412}
# 100%|██████████| 31/31 [00:00<00:00, 73.13it/s]
# {'ner': 121.8362503263298}
# 100%|██████████| 31/31 [00:00<00:00, 80.80it/s]
# {'ner': 123.95348926643099}
# 100%|██████████| 31/31 [00:00<00:00, 81.23it/s]
# {'ner': 126.75781361413864}
# 100%|██████████| 31/31 [00:00<00:00, 80.04it/s]
# {'ner': 114.26250731254511}
# 100%|██████████| 31/31 [00:00<00:00, 81.95it/s]
# {'ner': 99.3548051178024}
# 100%|██████████| 31/31 [00:00<00:00, 77.13it/s]
# {'ner': 98.83262172563265}
# 100%|██████████| 31/31 [00:00<00:00, 82.74it/s]
# {'ner': 109.92822820518236}
# 100%|██████████| 31/31 [00:00<00:00, 82.58it/s]
# {'ner': 110.12926451481903}
# 100%|██████████| 31/31 [00:00<00:00, 80.35it/s]
# {'ner': 76.35469584550083}
# 100%|██████████| 31/31 [00:00<00:00, 82.19it/s]
# {'ner': 79.39286640717339}
# 100%|██████████| 31/31 [00:00<00:00, 82.24it/s]
# {'ner': 98.82805911297432}
# 100%|██████████| 31/31 [00:00<00:00, 82.27it/s]
# {'ner': 85.84249866118819}
# 100%|██████████| 31/31 [00:00<00:00, 82.02it/s]
# {'ner': 85.08741706447275}
# 100%|██████████| 31/31 [00:00<00:00, 82.76it/s]
# {'ner': 91.14309153610587}
# 100%|██████████| 31/31 [00:00<00:00, 77.75it/s]
# {'ner': 82.20616080480863}
# 100%|██████████| 31/31 [00:00<00:00, 82.24it/s]
# {'ner': 78.2019926880512}
# 100%|██████████| 31/31 [00:00<00:00, 82.17it/s]
# {'ner': 83.91605972828013}
# 100%|██████████| 31/31 [00:00<00:00, 82.85it/s]
# {'ner': 67.1574175537916}
# 100%|██████████| 31/31 [00:00<00:00, 82.75it/s]
# {'ner': 110.30641336332621}
# 100%|██████████| 31/31 [00:00<00:00, 82.63it/s]
# {'ner': 73.87392652443157}
# 100%|██████████| 31/31 [00:00<00:00, 82.45it/s]
# {'ner': 88.76891649853195}
# 100%|██████████| 31/31 [00:00<00:00, 82.48it/s]
# {'ner': 62.140642151919224}
# 100%|██████████| 31/31 [00:00<00:00, 82.51it/s]
# {'ner': 61.58763159803968}
# 100%|██████████| 31/31 [00:00<00:00, 76.93it/s]
# {'ner': 58.20427252861253}
# 100%|██████████| 31/31 [00:00<00:00, 82.81it/s]
# {'ner': 73.24328671410044}
# 100%|██████████| 31/31 [00:00<00:00, 82.38it/s]
# {'ner': 72.90203213391213}
# 100%|██████████| 31/31 [00:00<00:00, 81.67it/s]
# {'ner': 40.183011806486654}
# 100%|██████████| 31/31 [00:00<00:00, 82.69it/s]
# {'ner': 84.35267154179908}
# 100%|██████████| 31/31 [00:00<00:00, 81.97it/s]
# {'ner': 59.27750394450004}
# 100%|██████████| 31/31 [00:00<00:00, 79.50it/s]
# {'ner': 94.10358983715533}
# 100%|██████████| 31/31 [00:00<00:00, 81.34it/s]
# {'ner': 53.13480264536272}
# 100%|██████████| 31/31 [00:00<00:00, 78.89it/s]
# {'ner': 64.67557370006428}
# 100%|██████████| 31/31 [00:00<00:00, 74.50it/s]
# {'ner': 54.47531811464736}
# 100%|██████████| 31/31 [00:00<00:00, 82.33it/s]
# {'ner': 77.89096298072062}
# 100%|██████████| 31/31 [00:00<00:00, 82.42it/s]
# {'ner': 61.442109741733674}
# 100%|██████████| 31/31 [00:00<00:00, 82.64it/s]
# {'ner': 57.75193529695368}
# 100%|██████████| 31/31 [00:00<00:00, 82.45it/s]
# {'ner': 42.805538947348545}
# 100%|██████████| 31/31 [00:00<00:00, 82.60it/s]
# {'ner': 59.93375707848889}
# 100%|██████████| 31/31 [00:00<00:00, 80.75it/s]
# {'ner': 51.14118389957376}
# 100%|██████████| 31/31 [00:00<00:00, 78.40it/s]
# {'ner': 45.38783609075748}
# 100%|██████████| 31/31 [00:00<00:00, 84.73it/s]
# {'ner': 47.653169962143686}
# 100%|██████████| 31/31 [00:00<00:00, 85.35it/s]
# {'ner': 52.036474302880926}
# 100%|██████████| 31/31 [00:00<00:00, 85.41it/s]
# {'ner': 51.31606878675281}
# 100%|██████████| 31/31 [00:00<00:00, 85.71it/s]
# {'ner': 68.20029088065004}
# 100%|██████████| 31/31 [00:00<00:00, 86.53it/s]
# {'ner': 46.59918236029379}
# 100%|██████████| 31/31 [00:00<00:00, 79.10it/s]
# {'ner': 45.46004651518803}
# 100%|██████████| 31/31 [00:00<00:00, 67.04it/s]
# {'ner': 36.003943076603704}
# 100%|██████████| 31/31 [00:00<00:00, 76.86it/s]
# {'ner': 28.48073139578559}
# 100%|██████████| 31/31 [00:00<00:00, 82.97it/s]
# {'ner': 45.74753610265821}
# 100%|██████████| 31/31 [00:00<00:00, 78.87it/s]
# {'ner': 50.35194180103279}
# 100%|██████████| 31/31 [00:00<00:00, 79.17it/s]
# {'ner': 33.59984976097147}
# 100%|██████████| 31/31 [00:00<00:00, 79.94it/s]
# {'ner': 41.91905209621664}
# 100%|██████████| 31/31 [00:00<00:00, 79.92it/s]
# {'ner': 32.833154104585056}
# 100%|██████████| 31/31 [00:00<00:00, 76.30it/s]
# {'ner': 35.38371870071802}
# 100%|██████████| 31/31 [00:00<00:00, 83.90it/s]
# {'ner': 50.781888568879694}
# 100%|██████████| 31/31 [00:00<00:00, 80.54it/s]
# {'ner': 36.82392651336295}
# 100%|██████████| 31/31 [00:00<00:00, 85.12it/s]
# {'ner': 38.36881006607929}
# 100%|██████████| 31/31 [00:00<00:00, 84.56it/s]
# {'ner': 27.054100542857658}
# 100%|██████████| 31/31 [00:00<00:00, 84.21it/s]
# {'ner': 16.771503538299026}
# 100%|██████████| 31/31 [00:00<00:00, 84.18it/s]
# {'ner': 45.22882965795594}
# 100%|██████████| 31/31 [00:00<00:00, 84.87it/s]
# {'ner': 48.065608580371034}
# 100%|██████████| 31/31 [00:00<00:00, 76.80it/s]
# {'ner': 19.537979260562864}
# 100%|██████████| 31/31 [00:00<00:00, 69.34it/s]
# {'ner': 16.280409569208356}
# Entities [('Microsoft', 'VENDOR'), ('Office Publisher', 'PRODUCT'), ('security feature bypass', 'VULNERABILITY NAME'), ('local, authenticated attack', 'ACTOR'), ('targeted system', 'MODULE')]
# Tokens [('Microsoft', 'VENDOR', 3), ('Office', 'PRODUCT', 3), ('Publisher', 'PRODUCT', 1), ('contains', '', 2), ('a', '', 2), ('security', 'VULNERABILITY NAME', 3), ('feature', 'VULNERABILITY NAME', 1), ('bypass', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('for', '', 2), ('a', '', 2), ('local', 'ACTOR', 3), (',', 'ACTOR', 1), ('authenticated', 'ACTOR', 1), ('attack', 'ACTOR', 1), ('on', '', 2), ('a', '', 2), ('targeted', 'MODULE', 3), ('system', 'MODULE', 1), ('.', '', 2)]
# Entities [('Microsoft', 'VENDOR'), ('Exchange Server', 'PRODUCT'), ('unspecified', 'VULNERABILITY NAME'), ('remote code execution.', 'EXPLOIT'), ('ProxyLogon', 'EXPLOIT')]
# Tokens [('Microsoft', 'VENDOR', 3), ('Exchange', 'PRODUCT', 3), ('Server', 'PRODUCT', 1), ('contains', '', 2), ('an', '', 2), ('unspecified', 'VULNERABILITY NAME', 3), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('for', '', 2), ('remote', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('execution', 'EXPLOIT', 1), ('.', 'EXPLOIT', 1), ('This', '', 2), ('vulnerability', '', 2), ('is', '', 2), ('part', '', 2), ('of', '', 2), ('the', '', 2), ('ProxyLogon', 'EXPLOIT', 3), ('exploit', '', 2), ('chain', '', 2), ('.', '', 2)]
# Entities [('Unspecified', 'VULNERABILITY NAME'), ('Adobe', 'VENDOR'), ('Flash Player', 'PRODUCT'), ('remote attackers', 'ACTOR'), ('execute arbitrary code', 'EXPLOIT'), ('denial of service', 'EXPLOIT'), ('crafted SWF content', 'MODULE')]
# Tokens [('Unspecified', 'VULNERABILITY NAME', 3), ('vulnerability', '', 2), ('in', '', 2), ('Adobe', 'VENDOR', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('allows', '', 2), ('remote', 'ACTOR', 3), ('attackers', 'ACTOR', 1), ('to', '', 2), ('execute', 'EXPLOIT', 3), ('arbitrary', 'EXPLOIT', 1), ('code', 'EXPLOIT', 1), ('or', '', 2), ('cause', '', 2), ('a', '', 2), ('denial', 'EXPLOIT', 3), ('of', 'EXPLOIT', 1), ('service', 'EXPLOIT', 1), ('via', '', 2), ('crafted', 'MODULE', 3), ('SWF', 'MODULE', 1), ('content', 'MODULE', 1), ('.', '', 2)]
# Entities [('Trend Micro', 'VENDOR'), ('OfficeScan', 'PRODUCT'), ('directory traversal', 'VULNERABILITY NAME'), ('OfficeScan', 'PRODUCT'), ('remote code execution', 'EXPLOIT')]
# Tokens [('Trend', 'VENDOR', 3), ('Micro', 'VENDOR', 1), ('OfficeScan', 'PRODUCT', 3), ('contains', '', 2), ('a', '', 2), ('directory', 'VULNERABILITY NAME', 3), ('traversal', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('by', '', 2), ('extracting', '', 2), ('files', '', 2), ('from', '', 2), ('a', '', 2), ('zip', '', 2), ('file', '', 2), ('to', '', 2), ('a', '', 2), ('specific', '', 2), ('folder', '', 2), ('on', '', 2), ('the', '', 2), ('OfficeScan', 'PRODUCT', 3), ('server', '', 2), (',', '', 2), ('leading', '', 2), ('to', '', 2), ('remote', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('execution', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Adobe', 'VENDOR'), ('Flash Player', 'PRODUCT'), ('dereferenced memory pointer', 'MODULE'), ('code execution', 'EXPLOIT')]
# Tokens [('Adobe', 'VENDOR', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('has', '', 2), ('a', '', 2), ('vulnerability', '', 2), ('in', '', 2), ('the', '', 2), ('way', '', 2), ('it', '', 2), ('handles', '', 2), ('a', '', 2), ('dereferenced', 'MODULE', 3), ('memory', 'MODULE', 1), ('pointer', 'MODULE', 1), ('which', '', 2), ('could', '', 2), ('lead', '', 2), ('to', '', 2), ('code', 'EXPLOIT', 3), ('execution', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('WhatsApp', 'VENDOR'), ('Desktop', 'PRODUCT'), ('WhatsApp', 'VENDOR'), ('iPhone', 'PRODUCT'), ('cross-site scripting', 'EXPLOIT'), ('local file reading', 'EXPLOIT')]
# Tokens [('A', '', 2), ('vulnerability', '', 2), ('in', '', 2), ('WhatsApp', 'VENDOR', 3), ('Desktop', 'PRODUCT', 3), ('when', '', 2), ('paired', '', 2), ('with', '', 2), ('WhatsApp', 'VENDOR', 3), ('for', '', 2), ('iPhone', 'PRODUCT', 3), ('allows', '', 2), ('cross', 'EXPLOIT', 3), ('-', 'EXPLOIT', 1), ('site', 'EXPLOIT', 1), ('scripting', 'EXPLOIT', 1), ('and', '', 2), ('local', 'EXPLOIT', 3), ('file', 'EXPLOIT', 1), ('reading', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('SQL Injection', 'VULNERABILITY NAME'), ('U.motion', 'VENDOR'), ('Builder software', 'PRODUCT'), ('unwanted code execution', 'EXPLOIT')]
# Tokens [('A', '', 2), ('SQL', 'VULNERABILITY NAME', 3), ('Injection', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('exists', '', 2), ('in', '', 2), ('U.motion', 'VENDOR', 3), ('Builder', 'PRODUCT', 3), ('software', 'PRODUCT', 1), ('which', '', 2), ('could', '', 2), ('cause', '', 2), ('unwanted', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('execution', 'EXPLOIT', 1), ('when', '', 2), ('an', '', 2), ('improper', '', 2), ('set', '', 2), ('of', '', 2), ('characters', '', 2), ('is', '', 2), ('entered', '', 2), ('.', '', 2)]
# Entities [('Veeam', 'VENDOR'), ('Distribution Service', 'PRODUCT'), ('Backup & Replication', 'FEATURE'), ('unauthenticated users', 'ACTOR'), ('access internal API functions.', 'EXPLOIT'), ('remote attacker', 'ACTOR'), ('internal API', 'MODULE'), ('uploading and executing of malicious code', 'EXPLOIT')]
# Tokens [('The', '', 2), ('Veeam', 'VENDOR', 3), ('Distribution', 'PRODUCT', 3), ('Service', 'PRODUCT', 1), ('in', '', 2), ('the', '', 2), ('Backup', 'FEATURE', 3), ('&', 'FEATURE', 1), ('Replication', 'FEATURE', 1), ('application', '', 2), ('allows', '', 2), ('unauthenticated', 'ACTOR', 3), ('users', 'ACTOR', 1), ('to', '', 2), ('access', 'EXPLOIT', 3), ('internal', 'EXPLOIT', 1), ('API', 'EXPLOIT', 1), ('functions', 'EXPLOIT', 1), ('.', 'EXPLOIT', 1), ('A', '', 2), ('remote', 'ACTOR', 3), ('attacker', 'ACTOR', 1), ('can', '', 2), ('send', '', 2), ('input', '', 2), ('to', '', 2), ('the', '', 2), ('internal', 'MODULE', 3), ('API', 'MODULE', 1), ('which', '', 2), ('may', '', 2), ('lead', '', 2), ('to', '', 2), ('uploading', 'EXPLOIT', 3), ('and', 'EXPLOIT', 1), ('executing', 'EXPLOIT', 1), ('of', 'EXPLOIT', 1), ('malicious', 'EXPLOIT', 1), ('code', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Apple', 'VENDOR'), ('iOS', 'PRODUCT'), ('iPadOS', 'PRODUCT'), ('macOS', 'PRODUCT'), ('watchOS', 'PRODUCT'), ('unspecified', 'VULNERABILITY NAME'), ('local privilege escalation', 'EXPLOIT')]
# Tokens [('Apple', 'VENDOR', 3), ('iOS', 'PRODUCT', 3), (',', '', 2), ('iPadOS', 'PRODUCT', 3), (',', '', 2), ('macOS', 'PRODUCT', 3), (',', '', 2), ('and', '', 2), ('watchOS', 'PRODUCT', 3), ('contain', '', 2), ('an', '', 2), ('unspecified', 'VULNERABILITY NAME', 3), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('for', '', 2), ('local', 'EXPLOIT', 3), ('privilege', 'EXPLOIT', 1), ('escalation', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Mozilla', 'VENDOR'), ('Firefox', 'PRODUCT'), ('Thunderbird', 'PRODUCT'), ('race condition', 'VULNERABILITY NAME'), ('nsDocShell destructor', 'FEATURE'), ('use-after-free', 'VULNERABILITY NAME'), ('unspecified impacts', 'EXPLOIT')]
# Tokens [('Mozilla', 'VENDOR', 3), ('Firefox', 'PRODUCT', 3), ('and', '', 2), ('Thunderbird', 'PRODUCT', 3), ('contain', '', 2), ('a', '', 2), ('race', 'VULNERABILITY NAME', 3), ('condition', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('when', '', 2), ('running', '', 2), ('the', '', 2), ('nsDocShell', 'FEATURE', 3), ('destructor', 'FEATURE', 1), ('under', '', 2), ('certain', '', 2), ('conditions', '', 2), ('.', '', 2), ('The', '', 2), ('race', '', 2), ('condition', '', 2), ('creates', '', 2), ('a', '', 2), ('use', 'VULNERABILITY NAME', 3), ('-', 'VULNERABILITY NAME', 1), ('after', 'VULNERABILITY NAME', 1), ('-', 'VULNERABILITY NAME', 1), ('free', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), (',', '', 2), ('causing', '', 2), ('unspecified', 'EXPLOIT', 3), ('impacts', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('cross-site scripting', 'VULNERABILITY NAME'), ('QNAP', 'VENDOR'), ('NAS File Station', 'PRODUCT'), ('remote attackers', 'ACTOR'), ('inject malicious code', 'EXPLOIT')]
# Tokens [('A', '', 2), ('cross', 'VULNERABILITY NAME', 3), ('-', 'VULNERABILITY NAME', 1), ('site', 'VULNERABILITY NAME', 1), ('scripting', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('affecting', '', 2), ('QNAP', 'VENDOR', 3), ('NAS', 'PRODUCT', 3), ('File', 'PRODUCT', 1), ('Station', 'PRODUCT', 1), ('could', '', 2), ('allow', '', 2), ('remote', 'ACTOR', 3), ('attackers', 'ACTOR', 1), ('to', '', 2), ('inject', 'EXPLOIT', 3), ('malicious', 'EXPLOIT', 1), ('code', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Drupal', 'VENDOR'), ('Core', 'PRODUCT'), ('remote code execution', 'VULNERABILITY NAME'), ('attacker', 'ACTOR'), ('complete site compromise', 'EXPLOIT')]
# Tokens [('Drupal', 'VENDOR', 3), ('Core', 'PRODUCT', 3), ('contains', '', 2), ('a', '', 2), ('remote', 'VULNERABILITY NAME', 3), ('code', 'VULNERABILITY NAME', 1), ('execution', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('could', '', 2), ('allow', '', 2), ('an', '', 2), ('attacker', 'ACTOR', 3), ('to', '', 2), ('exploit', '', 2), ('multiple', '', 2), ('attack', '', 2), ('vectors', '', 2), ('on', '', 2), ('a', '', 2), ('Drupal', '', 2), ('site', '', 2), (',', '', 2), ('resulting', '', 2), ('in', '', 2), ('complete', 'EXPLOIT', 3), ('site', 'EXPLOIT', 1), ('compromise', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Google', 'VENDOR'), ('Chromium', 'PRODUCT'), ('WebP', 'FEATURE'), ('heap-based buffer overflow', 'VULNERABILITY NAME'), ('remote attacker', 'ACTOR'), ('out-of-bounds memory write', 'EXPLOIT'), ('crafted HTML page.', 'MODULE'), ('WebP Codec.', 'FEATURE')]
# Tokens [('Google', 'VENDOR', 3), ('Chromium', 'PRODUCT', 3), ('WebP', 'FEATURE', 3), ('contains', '', 2), ('a', '', 2), ('heap', 'VULNERABILITY NAME', 3), ('-', 'VULNERABILITY NAME', 1), ('based', 'VULNERABILITY NAME', 1), ('buffer', 'VULNERABILITY NAME', 1), ('overflow', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('a', '', 2), ('remote', 'ACTOR', 3), ('attacker', 'ACTOR', 1), ('to', '', 2), ('perform', '', 2), ('an', '', 2), ('out', 'EXPLOIT', 3), ('-', 'EXPLOIT', 1), ('of', 'EXPLOIT', 1), ('-', 'EXPLOIT', 1), ('bounds', 'EXPLOIT', 1), ('memory', 'EXPLOIT', 1), ('write', 'EXPLOIT', 1), ('via', '', 2), ('a', '', 2), ('crafted', 'MODULE', 3), ('HTML', 'MODULE', 1), ('page', 'MODULE', 1), ('.', 'MODULE', 1), ('This', '', 2), ('vulnerability', '', 2), ('can', '', 2), ('affect', '', 2), ('applications', '', 2), ('that', '', 2), ('use', '', 2), ('the', '', 2), ('WebP', 'FEATURE', 3), ('Codec', 'FEATURE', 1), ('.', 'FEATURE', 1)]
# Entities [('Nagios', 'VENDOR'), ('XI', 'PRODUCT'), ('remote code execution', 'VULNERABILITY NAME'), ('user', 'ACTOR'), ('modify the check_plugin executable', 'EXPLOIT'), ('insert malicious commands', 'EXPLOIT')]
# Tokens [('Nagios', 'VENDOR', 3), ('XI', 'PRODUCT', 3), ('contains', '', 2), ('a', '', 2), ('remote', 'VULNERABILITY NAME', 3), ('code', 'VULNERABILITY NAME', 1), ('execution', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('in', '', 2), ('which', '', 2), ('a', '', 2), ('user', 'ACTOR', 3), ('can', '', 2), ('modify', 'EXPLOIT', 3), ('the', 'EXPLOIT', 1), ('check_plugin', 'EXPLOIT', 1), ('executable', 'EXPLOIT', 1), ('and', '', 2), ('insert', 'EXPLOIT', 3), ('malicious', 'EXPLOIT', 1), ('commands', 'EXPLOIT', 1), ('to', '', 2), ('execute', '', 2), ('as', '', 2), ('root', '', 2), ('.', '', 2)]
# Entities [('Grandstream', 'VENDOR'), ('UCM6200', 'PRODUCT'), ('remote SQL injection', 'VULNERABILITY NAME'), ('crafted HTTP request.', 'MODULE'), ('code execution as root', 'EXPLOIT')]
# Tokens [('Grandstream', 'VENDOR', 3), ('UCM6200', 'PRODUCT', 3), ('series', '', 2), ('is', '', 2), ('vulnerable', '', 2), ('to', '', 2), ('an', '', 2), ('unauthenticated', '', 2), ('remote', 'VULNERABILITY NAME', 3), ('SQL', 'VULNERABILITY NAME', 1), ('injection', 'VULNERABILITY NAME', 1), ('via', '', 2), ('crafted', 'MODULE', 3), ('HTTP', 'MODULE', 1), ('request', 'MODULE', 1), ('.', 'MODULE', 1), ('Exploitation', '', 2), ('can', '', 2), ('allow', '', 2), ('for', '', 2), ('code', 'EXPLOIT', 3), ('execution', 'EXPLOIT', 1), ('as', 'EXPLOIT', 1), ('root', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Cisco', 'VENDOR'), ('IOS', 'PRODUCT'), ('XR Distance Vector Multicast Routing Protocol (DVMRP', 'FEATURE'), ('Internet Group Management Protocol (IGMP) packets.', 'MODULE'), ('unauthenticated, remote attacker', 'ACTOR'), ('crash the IGMP process', 'EXPLOIT'), ('make it consume available memory', 'EXPLOIT'), ('eventually crash', 'EXPLOIT')]
# Tokens [('Cisco', 'VENDOR', 3), ('IOS', 'PRODUCT', 3), ('XR', 'FEATURE', 3), ('Distance', 'FEATURE', 1), ('Vector', 'FEATURE', 1), ('Multicast', 'FEATURE', 1), ('Routing', 'FEATURE', 1), ('Protocol', 'FEATURE', 1), ('(', 'FEATURE', 1), ('DVMRP', 'FEATURE', 1), (')', '', 2), ('incorrectly', '', 2), ('handles', '', 2), ('Internet', 'MODULE', 3), ('Group', 'MODULE', 1), ('Management', 'MODULE', 1), ('Protocol', 'MODULE', 1), ('(', 'MODULE', 1), ('IGMP', 'MODULE', 1), (')', 'MODULE', 1), ('packets', 'MODULE', 1), ('.', 'MODULE', 1), ('Exploitation', '', 2), ('could', '', 2), ('allow', '', 2), ('an', '', 2), ('unauthenticated', 'ACTOR', 3), (',', 'ACTOR', 1), ('remote', 'ACTOR', 1), ('attacker', 'ACTOR', 1), ('to', '', 2), ('immediately', '', 2), ('crash', 'EXPLOIT', 3), ('the', 'EXPLOIT', 1), ('IGMP', 'EXPLOIT', 1), ('process', 'EXPLOIT', 1), ('or', '', 2), ('make', 'EXPLOIT', 3), ('it', 'EXPLOIT', 1), ('consume', 'EXPLOIT', 1), ('available', 'EXPLOIT', 1), ('memory', 'EXPLOIT', 1), ('and', '', 2), ('eventually', 'EXPLOIT', 3), ('crash', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Rejetto', 'VENDOR'), ('HTTP File Server', 'PRODUCT'), ('template engine', 'VULNERABILITY NAME'), ('remote, unauthenticated attacker', 'ACTOR'), ('execute commands on the affected system', 'EXPLOIT'), ('crafted HTTP request.', 'MODULE')]
# Tokens [('Rejetto', 'VENDOR', 3), ('HTTP', 'PRODUCT', 3), ('File', 'PRODUCT', 1), ('Server', 'PRODUCT', 1), ('contains', '', 2), ('an', '', 2), ('improper', '', 2), ('neutralization', '', 2), ('of', '', 2), ('special', '', 2), ('elements', '', 2), ('used', '', 2), ('in', '', 2), ('a', '', 2), ('template', 'VULNERABILITY NAME', 3), ('engine', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('.', '', 2), ('This', '', 2), ('allows', '', 2), ('a', '', 2), ('remote', 'ACTOR', 3), (',', 'ACTOR', 1), ('unauthenticated', 'ACTOR', 1), ('attacker', 'ACTOR', 1), ('to', '', 2), ('execute', 'EXPLOIT', 3), ('commands', 'EXPLOIT', 1), ('on', 'EXPLOIT', 1), ('the', 'EXPLOIT', 1), ('affected', 'EXPLOIT', 1), ('system', 'EXPLOIT', 1), ('by', '', 2), ('sending', '', 2), ('a', '', 2), ('specially', '', 2), ('crafted', 'MODULE', 3), ('HTTP', 'MODULE', 1), ('request', 'MODULE', 1), ('.', 'MODULE', 1)]
# Entities [('Adobe', 'VENDOR'), ('Flash Player', 'PRODUCT'), ('unspecified', 'VULNERABILITY NAME'), ('remote attackers', 'ACTOR'), ('execute code', 'EXPLOIT'), ('cause denial-of-service (DoS', 'EXPLOIT')]
# Tokens [('Adobe', 'VENDOR', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('contains', '', 2), ('an', '', 2), ('unspecified', 'VULNERABILITY NAME', 3), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('remote', 'ACTOR', 3), ('attackers', 'ACTOR', 1), ('to', '', 2), ('execute', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('or', '', 2), ('cause', 'EXPLOIT', 3), ('denial', 'EXPLOIT', 1), ('-', 'EXPLOIT', 1), ('of', 'EXPLOIT', 1), ('-', 'EXPLOIT', 1), ('service', 'EXPLOIT', 1), ('(', 'EXPLOIT', 1), ('DoS', 'EXPLOIT', 1), (')', '', 2), ('.', '', 2)]
# Entities [('Microsoft', 'VENDOR'), ('Windows', 'PRODUCT'), ('remote attackers', 'ACTOR'), ('execute arbitrary code', 'EXPLOIT'), ('crafted OLE object.', 'MODULE')]
# Tokens [('Microsoft', 'VENDOR', 3), ('Windows', 'PRODUCT', 3), ('allow', '', 2), ('remote', 'ACTOR', 3), ('attackers', 'ACTOR', 1), ('to', '', 2), ('execute', 'EXPLOIT', 3), ('arbitrary', 'EXPLOIT', 1), ('code', 'EXPLOIT', 1), ('via', '', 2), ('a', '', 2), ('crafted', 'MODULE', 3), ('OLE', 'MODULE', 1), ('object', 'MODULE', 1), ('.', 'MODULE', 1)]
# Entities [('F5', 'VENDOR'), ('BIG-IP', 'PRODUCT'), ('alternate path or channel', 'VULNERABILITY NAME'), ('unauthenticated attacker', 'ACTOR'), ('access to the BIG-IP system', 'EXPLOIT'), ('self IP addresses to execute system commands.', 'EXPLOIT'), ('CVE-2023-46748', 'VULNERABILITY NAME')]
# Tokens [('F5', 'VENDOR', 3), ('BIG', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('IP', 'PRODUCT', 1), ('Configuration', '', 2), ('utility', '', 2), ('contains', '', 2), ('an', '', 2), ('authentication', '', 2), ('bypass', '', 2), ('using', '', 2), ('an', '', 2), ('alternate', 'VULNERABILITY NAME', 3), ('path', 'VULNERABILITY NAME', 1), ('or', 'VULNERABILITY NAME', 1), ('channel', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('due', '', 2), ('to', '', 2), ('undisclosed', '', 2), ('requests', '', 2), ('that', '', 2), ('may', '', 2), ('allow', '', 2), ('an', '', 2), ('unauthenticated', 'ACTOR', 3), ('attacker', 'ACTOR', 1), ('with', '', 2), ('network', '', 2), ('access', 'EXPLOIT', 3), ('to', 'EXPLOIT', 1), ('the', 'EXPLOIT', 1), ('BIG', 'EXPLOIT', 1), ('-', 'EXPLOIT', 1), ('IP', 'EXPLOIT', 1), ('system', 'EXPLOIT', 1), ('through', '', 2), ('the', '', 2), ('management', '', 2), ('port', '', 2), ('and/or', '', 2), ('self', 'EXPLOIT', 3), ('IP', 'EXPLOIT', 1), ('addresses', 'EXPLOIT', 1), ('to', 'EXPLOIT', 1), ('execute', 'EXPLOIT', 1), ('system', 'EXPLOIT', 1), ('commands', 'EXPLOIT', 1), ('.', 'EXPLOIT', 1), ('This', '', 2), ('vulnerability', '', 2), ('can', '', 2), ('be', '', 2), ('used', '', 2), ('in', '', 2), ('conjunction', '', 2), ('with', '', 2), ('CVE-2023', 'VULNERABILITY NAME', 3), ('-', 'VULNERABILITY NAME', 1), ('46748', 'VULNERABILITY NAME', 1), ('.', '', 2)]
# Entities [('Veritas', 'VENDOR'), ('Backup Exec (BE)', 'PRODUCT'), ('file access', 'VULNERABILITY NAME'), ('attacker', 'ACTOR'), ('craft input parameters', 'EXPLOIT'), ('access files', 'EXPLOIT'), ('BE Agent machine', 'FEATURE')]
# Tokens [('Veritas', 'VENDOR', 3), ('Backup', 'PRODUCT', 3), ('Exec', 'PRODUCT', 1), ('(', 'PRODUCT', 1), ('BE', 'PRODUCT', 1), (')', 'PRODUCT', 1), ('Agent', '', 2), ('contains', '', 2), ('a', '', 2), ('file', 'VULNERABILITY NAME', 3), ('access', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('could', '', 2), ('allow', '', 2), ('an', '', 2), ('attacker', 'ACTOR', 3), ('to', '', 2), ('specially', '', 2), ('craft', 'EXPLOIT', 3), ('input', 'EXPLOIT', 1), ('parameters', 'EXPLOIT', 1), ('on', '', 2), ('a', '', 2), ('data', '', 2), ('management', '', 2), ('protocol', '', 2), ('command', '', 2), ('to', '', 2), ('access', 'EXPLOIT', 3), ('files', 'EXPLOIT', 1), ('on', '', 2), ('the', '', 2), ('BE', 'FEATURE', 3), ('Agent', 'FEATURE', 1), ('machine', 'FEATURE', 1), ('.', '', 2)]
# Entities [('Android', 'VENDOR'), ('kernel', 'PRODUCT'), ('use-after-free', 'VULNERABILITY NAME'), ('privilege escalation', 'EXPLOIT')]
# Tokens [('Android', 'VENDOR', 3), ('kernel', 'PRODUCT', 3), ('contains', '', 2), ('a', '', 2), ('race', '', 2), ('condition', '', 2), (',', '', 2), ('which', '', 2), ('allows', '', 2), ('for', '', 2), ('a', '', 2), ('use', 'VULNERABILITY NAME', 3), ('-', 'VULNERABILITY NAME', 1), ('after', 'VULNERABILITY NAME', 1), ('-', 'VULNERABILITY NAME', 1), ('free', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('.', '', 2), ('Exploitation', '', 2), ('can', '', 2), ('allow', '', 2), ('for', '', 2), ('privilege', 'EXPLOIT', 3), ('escalation', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('D-Link', 'VENDOR'), ('DSL-2750B', 'PRODUCT'), ('command injection', 'VULNERABILITY NAME'), ('remote, unauthenticated command injection', 'EXPLOIT'), ('login.cgi cli parameter', 'MODULE')]
# Tokens [('D', 'VENDOR', 3), ('-', 'VENDOR', 1), ('Link', 'VENDOR', 1), ('DSL-2750B', 'PRODUCT', 3), ('devices', '', 2), ('contain', '', 2), ('a', '', 2), ('command', 'VULNERABILITY NAME', 3), ('injection', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('remote', 'EXPLOIT', 3), (',', 'EXPLOIT', 1), ('unauthenticated', 'EXPLOIT', 1), ('command', 'EXPLOIT', 1), ('injection', 'EXPLOIT', 1), ('via', '', 2), ('the', '', 2), ('login.cgi', 'MODULE', 3), ('cli', 'MODULE', 1), ('parameter', 'MODULE', 1), ('.', '', 2)]
# Entities [('Roundcube', 'VENDOR'), ('Webmail', 'PRODUCT'), ('SQL injection', 'VULNERABILITY NAME'), ('search', 'MODULE'), ('search_params', 'MODULE')]
# Tokens [('Roundcube', 'VENDOR', 3), ('Webmail', 'PRODUCT', 3), ('is', '', 2), ('vulnerable', '', 2), ('to', '', 2), ('SQL', 'VULNERABILITY NAME', 3), ('injection', 'VULNERABILITY NAME', 1), ('via', '', 2), ('search', 'MODULE', 3), ('or', '', 2), ('search_params', 'MODULE', 3), ('.', '', 2)]
# Entities [('VMware', 'VENDOR'), ('vCenter', 'PRODUCT'), ('Cloud Foundation', 'PRODUCT'), ('SSRF', 'VULNERABILITY NAME'), ('vCenter', 'PRODUCT'), ('plugin.', 'MODULE'), ('information disclosure.', 'EXPLOIT')]
# Tokens [('VMware', 'VENDOR', 3), ('vCenter', 'PRODUCT', 3), ('Server', '', 2), ('and', '', 2), ('Cloud', 'PRODUCT', 3), ('Foundation', 'PRODUCT', 1), ('Server', '', 2), ('contain', '', 2), ('a', '', 2), ('SSRF', 'VULNERABILITY NAME', 3), ('vulnerability', '', 2), ('due', '', 2), ('to', '', 2), ('improper', '', 2), ('validation', '', 2), ('of', '', 2), ('URLs', '', 2), ('in', '', 2), ('a', '', 2), ('vCenter', 'PRODUCT', 3), ('Server', '', 2), ('plugin', 'MODULE', 3), ('.', 'MODULE', 1), ('This', '', 2), ('allows', '', 2), ('for', '', 2), ('information', 'EXPLOIT', 3), ('disclosure', 'EXPLOIT', 1), ('.', 'EXPLOIT', 1)]
# Entities [('Trend Micro', 'VENDOR'), ('Apex One', 'PRODUCT'), ('OfficeScan', 'PRODUCT'), ('Worry-Free Business Security', 'PRODUCT'), ('Microsoft', 'VENDOR'), ('Windows', 'PRODUCT'), ('improper access control', 'VULNERABILITY NAME'), ('attacker', 'ACTOR'), ('disable the security temporarily', 'EXPLOIT'), ('abuse a specific Windows function', 'EXPLOIT'), ('attain privilege escalation', 'EXPLOIT')]
# Tokens [('Trend', 'VENDOR', 3), ('Micro', 'VENDOR', 1), ('Apex', 'PRODUCT', 3), ('One', 'PRODUCT', 1), (',', '', 2), ('OfficeScan', 'PRODUCT', 3), (',', '', 2), ('and', '', 2), ('Worry', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('Free', 'PRODUCT', 1), ('Business', 'PRODUCT', 1), ('Security', 'PRODUCT', 1), ('on', '', 2), ('Microsoft', 'VENDOR', 3), ('Windows', 'PRODUCT', 3), ('contain', '', 2), ('an', '', 2), ('improper', 'VULNERABILITY NAME', 3), ('access', 'VULNERABILITY NAME', 1), ('control', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('may', '', 2), ('allow', '', 2), ('an', '', 2), ('attacker', 'ACTOR', 3), ('to', '', 2), ('manipulate', '', 2), ('a', '', 2), ('particular', '', 2), ('product', '', 2), ('folder', '', 2), ('to', '', 2), ('disable', 'EXPLOIT', 3), ('the', 'EXPLOIT', 1), ('security', 'EXPLOIT', 1), ('temporarily', 'EXPLOIT', 1), (',', '', 2), ('abuse', 'EXPLOIT', 3), ('a', 'EXPLOIT', 1), ('specific', 'EXPLOIT', 1), ('Windows', 'EXPLOIT', 1), ('function', 'EXPLOIT', 1), (',', '', 2), ('and', '', 2), ('attain', 'EXPLOIT', 3), ('privilege', 'EXPLOIT', 1), ('escalation', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Cisco', 'VENDOR'), ('IP', 'VENDOR'), ('improper input validation', 'VULNERABILITY NAME'), ('HTTP requests.', 'MODULE'), ('attacker', 'ACTOR'), ('execute code remotely', 'EXPLOIT'), ('denial-of-service (DoS', 'EXPLOIT')]
# Tokens [('Cisco', 'VENDOR', 3), ('IP', 'VENDOR', 3), ('Phones', '', 2), ('contain', '', 2), ('an', '', 2), ('improper', 'VULNERABILITY NAME', 3), ('input', 'VULNERABILITY NAME', 1), ('validation', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('for', '', 2), ('HTTP', 'MODULE', 3), ('requests', 'MODULE', 1), ('.', 'MODULE', 1), ('Exploitation', '', 2), ('could', '', 2), ('allow', '', 2), ('an', '', 2), ('attacker', 'ACTOR', 3), ('to', '', 2), ('execute', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('remotely', 'EXPLOIT', 1), ('with', '', 2), ('root', '', 2), ('privileges', '', 2), ('or', '', 2), ('cause', '', 2), ('a', '', 2), ('denial', 'EXPLOIT', 3), ('-', 'EXPLOIT', 1), ('of', 'EXPLOIT', 1), ('-', 'EXPLOIT', 1), ('service', 'EXPLOIT', 1), ('(', 'EXPLOIT', 1), ('DoS', 'EXPLOIT', 1), (')', '', 2), ('condition', '', 2), ('.', '', 2)]
# Entities [('D-Link', 'VENDOR'), ('command injection', 'VULNERABILITY NAME'), ('attackers', 'ACTOR'), ('full system compromise', 'EXPLOIT')]
# Tokens [('Multiple', '', 2), ('D', 'VENDOR', 3), ('-', 'VENDOR', 1), ('Link', 'VENDOR', 1), ('routers', '', 2), ('contain', '', 2), ('a', '', 2), ('command', 'VULNERABILITY NAME', 3), ('injection', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('which', '', 2), ('can', '', 2), ('allow', '', 2), ('attackers', 'ACTOR', 3), ('to', '', 2), ('achieve', '', 2), ('full', 'EXPLOIT', 3), ('system', 'EXPLOIT', 1), ('compromise', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Palo Alto Networks', 'VENDOR'), ('PAN-OS', 'PRODUCT'), ('unspecified', 'VULNERABILITY NAME'), ('remote code execution', 'EXPLOIT')]
# Tokens [('Palo', 'VENDOR', 3), ('Alto', 'VENDOR', 1), ('Networks', 'VENDOR', 1), ('PAN', 'PRODUCT', 3), ('-', 'PRODUCT', 1), ('OS', 'PRODUCT', 1), ('contains', '', 2), ('multiple', '', 2), (',', '', 2), ('unspecified', 'VULNERABILITY NAME', 3), ('vulnerabilities', '', 2), ('which', '', 2), ('can', '', 2), ('allow', '', 2), ('for', '', 2), ('remote', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('execution', 'EXPLOIT', 1), ('when', '', 2), ('chained', '', 2), ('.', '', 2)]
# Entities [('privilege escalation', 'FEATURE'), ('Windows', 'PRODUCT'), ('AppX Deployment Server', 'FEATURE')]
# Tokens [('A', '', 2), ('privilege', 'FEATURE', 3), ('escalation', 'FEATURE', 1), ('vulnerability', '', 2), ('exists', '', 2), ('when', '', 2), ('the', '', 2), ('Windows', 'PRODUCT', 3), ('AppX', 'FEATURE', 3), ('Deployment', 'FEATURE', 1), ('Server', 'FEATURE', 1), ('improperly', '', 2), ('handles', '', 2), ('junctions', '', 2), ('.', '', 2)]
# Entities [('Google', 'VENDOR'), ('Chromium', 'PRODUCT'), ('use-after-free', 'VULNERABILITY NAME'), ('remote attacker', 'ACTOR'), ('renderer process', 'MODULE'), ('sandbox escape', 'EXPLOIT'), ('crafted HTML page.', 'MODULE'), ('affects web browsers', 'EXPLOIT'), ('Chromium', 'PRODUCT'), ('Google', 'VENDOR'), ('Chrome', 'PRODUCT'), ('Microsoft', 'VENDOR'), ('Edge', 'PRODUCT')]
# Tokens [('Google', 'VENDOR', 3), ('Chromium', 'PRODUCT', 3), ('Portals', '', 2), ('contains', '', 2), ('a', '', 2), ('use', 'VULNERABILITY NAME', 3), ('-', 'VULNERABILITY NAME', 1), ('after', 'VULNERABILITY NAME', 1), ('-', 'VULNERABILITY NAME', 1), ('free', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('that', '', 2), ('allows', '', 2), ('a', '', 2), ('remote', 'ACTOR', 3), ('attacker', 'ACTOR', 1), (',', '', 2), ('who', '', 2), ('has', '', 2), ('compromised', '', 2), ('the', '', 2), ('renderer', 'MODULE', 3), ('process', 'MODULE', 1), (',', '', 2), ('to', '', 2), ('potentially', '', 2), ('perform', '', 2), ('a', '', 2), ('sandbox', 'EXPLOIT', 3), ('escape', 'EXPLOIT', 1), ('via', '', 2), ('a', '', 2), ('crafted', 'MODULE', 3), ('HTML', 'MODULE', 1), ('page', 'MODULE', 1), ('.', 'MODULE', 1), ('This', '', 2), ('vulnerability', '', 2), ('affects', 'EXPLOIT', 3), ('web', 'EXPLOIT', 1), ('browsers', 'EXPLOIT', 1), ('that', '', 2), ('utilize', '', 2), ('Chromium', 'PRODUCT', 3), (',', '', 2), ('including', '', 2), ('Google', 'VENDOR', 3), ('Chrome', 'PRODUCT', 3), ('and', '', 2), ('Microsoft', 'VENDOR', 3), ('Edge', 'PRODUCT', 3), ('.', '', 2)]
# Saved model to /Users/dj/Desktop/Capstone/Capstone
# Loading from /Users/dj/Desktop/Capstone/Capstone
# Entities [('Trend Micro', 'VENDOR'), ('OfficeScan', 'PRODUCT'), ('directory traversal', 'VULNERABILITY NAME'), ('OfficeScan', 'PRODUCT'), ('remote code execution', 'EXPLOIT')]
# Tokens [('Trend', 'VENDOR', 3), ('Micro', 'VENDOR', 1), ('OfficeScan', 'PRODUCT', 3), ('contains', '', 2), ('a', '', 2), ('directory', 'VULNERABILITY NAME', 3), ('traversal', 'VULNERABILITY NAME', 1), ('vulnerability', '', 2), ('by', '', 2), ('extracting', '', 2), ('files', '', 2), ('from', '', 2), ('a', '', 2), ('zip', '', 2), ('file', '', 2), ('to', '', 2), ('a', '', 2), ('specific', '', 2), ('folder', '', 2), ('on', '', 2), ('the', '', 2), ('OfficeScan', 'PRODUCT', 3), ('server', '', 2), (',', '', 2), ('leading', '', 2), ('to', '', 2), ('remote', 'EXPLOIT', 3), ('code', 'EXPLOIT', 1), ('execution', 'EXPLOIT', 1), ('.', '', 2)]
# Entities [('Adobe', 'VENDOR'), ('Flash Player', 'PRODUCT'), ('dereferenced memory pointer', 'MODULE'), ('code execution', 'EXPLOIT')]
# Tokens [('Adobe', 'VENDOR', 3), ('Flash', 'PRODUCT', 3), ('Player', 'PRODUCT', 1), ('has', '', 2), ('a', '', 2), ('vulnerability', '', 2), ('in', '', 2), ('the', '', 2), ('way', '', 2), ('it', '', 2), ('handles', '', 2), ('a', '', 2), ('dereferenced', 'MODULE', 3), ('memory', 'MODULE', 1), ('pointer', 'MODULE', 1), ('which', '', 2), ('could', '', 2), ('lead', '', 2), ('to', '', 2), ('code', 'EXPLOIT', 3), ('execution', 'EXPLOIT', 1), ('.', '', 2)]
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VENDOR</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chromium
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  Skia contains an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     integer overflow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VULNERABILITY NAME</span>
# </mark>
#  vulnerability that allows a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     remote attacker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACTOR</span>
# </mark>
# , who has compromised the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     renderer process
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MODULE</span>
# </mark>
# , to potentially perform a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sandbox escape
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
#  via a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     crafted HTML page.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MODULE</span>
# </mark>
#  This vulnerability
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     affects Google Chrome and
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ChromeOS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VENDOR</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flutter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     possibly other products
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RealTek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VENDOR</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jungle SDK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  contains multiple memory corruption vulnerabilities which can allow an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     attacker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACTOR</span>
# </mark>
#  to perform
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     remote code execution
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VENDOR</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kernel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  contains a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     race condition
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VULNERABILITY NAME</span>
# </mark>
#  vulnerability within the n_tty_write function that allows
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     local users
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ACTOR</span>
# </mark>
#  to cause a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     denial-of-service (DoS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
# ) or
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gain privileges
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
#  via read and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     write operations
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EXPLOIT</span>
# </mark>
#  with long strings.<br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Primetek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VENDOR</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     P
